# %% [markdown]
# ## **Preparação de ambiente**

# %%
import matplotlib
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns

from matplotlib import lines, patches

from matplotlib.colors import LinearSegmentedColormap
from matplotlib.patheffects import withStroke
from PIL import Image
from scipy.stats import pearsonr, spearmanr
from wordcloud import WordCloud, ImageColorGenerator

# %% [markdown]
# ## **Funções auxiliares**

# %%
def tabula(atributo,total):
    tabela = atributo.value_counts()
    tabela_frequencia = pd.DataFrame({tabela.index.name: tabela.index})
    tabela_frequencia['F.A.'] = list(tabela)
    tabela_frequencia['F.R.'] = np.nan
    for registro in tabela_frequencia['F.R.']:
        tabela_frequencia['F.R.'] = (tabela_frequencia['F.A.']/total).round(3)
    return tabela_frequencia
    
def consolida_vies(geral, positivos, negativos, coluna, linha):
    #consolidado = geral
    consolidado = geral.copy()
    consolidado.rename(columns={'F.A.': 'Frequência absoluta (ni)', 'F.R.': 'Frequência relativa (fi)'}, inplace = True)
    positivos.rename(columns = {'F.A.': 'Positivos (ni)', 'F.R.': 'Positivos (fi)'}, inplace = True)
    negativos.rename(columns = {'F.A.': 'Negativos (ni)', 'F.R.': 'Negativos (fi)'}, inplace = True)
    consolidado = pd.merge(consolidado, positivos, on = coluna, how = 'left') 
    consolidado = pd.merge(consolidado, negativos, on = coluna, how = 'left')     
    valores = consolidado.iloc[:, 1:]
    totais = valores.sum(axis = 0)
    consolidado.loc[linha, coluna] = ('Total')
    consolidado.iloc[linha, 1:] = totais
    colunas_frequencia_absoluta = ['Frequência absoluta (ni)', 'Positivos (ni)', 'Negativos (ni)']
    for coluna in colunas_frequencia_absoluta:
        consolidado[coluna] = consolidado[coluna].fillna(0) # substitui NaN por 0
        consolidado[coluna] = consolidado[coluna].replace([np.inf, -np.inf], 0)  # substitui infinitos por 0
        consolidado[coluna] = consolidado[coluna].astype(int) # converte para inteiros
    consolidado = consolidado.fillna(0) # substitui NaN por 0   
    return consolidado
    
def cria_tabela_consolidada(df_geral, total_geral, df_positivo, df_negativo, coluna, linha):
    total_positivos = len(df_positivo.index)
    total_negativos = len(df_negativo.index)
    frequencia_geral = tabula(df_geral[coluna], total_geral)
    frequencia_positivos = tabula(df_positivo[coluna], total_positivos)
    frequencia_negativos = tabula(df_negativo[coluna], total_negativos)
    tabela_consolidada = consolida_vies(frequencia_geral,frequencia_positivos,frequencia_negativos, coluna, linha)
    return tabela_consolidada

def cria_tabela_impressao(dataframe, rotulo, linha_total):
    tabela = dataframe.copy()
    tabela.rename(columns = {'Frequência absoluta (ni)': rotulo}, inplace = True)
    tabela['Positivos (fi)'] = (tabela['Positivos (ni)']/tabela[rotulo]).round(2)
    tabela['Negativos (fi)'] = (tabela['Negativos (ni)']/tabela[rotulo]).round(2)
    tabela['Frequência relativa (fi)'] = (tabela['Frequência relativa (fi)']).round(2)
    tabela.drop(linha_total, inplace = True)
    return tabela 

def gera_tabela_latex(dataframe, caption, label, fonte):
    # copia o dataframe para evitar modificar o original
    formatado = dataframe.copy()
     # substitui os pontos por vírgulas nos valores do dataframe
    colunas_float = dataframe.select_dtypes(include=['float'])
    for coluna in  colunas_float.columns:
        formatado[coluna] = formatado[coluna].apply(lambda x: f"{x:.2f}".replace('.', ','))
    # usa a função to_latex para gerar o código LaTeX
    codigo_latex = formatado.to_latex(index = False, escape = False)  
    # imprime o código LaTeX na tela
    print(r'\begin{table}[!htp]')
    print(r'\centering')
    print(r'\caption{' + caption + '}')
    print(r'\label{' + label + '}')
    print(r'\footnotesize')
    print(r'\renewcommand{\arraystretch}{1.5}')
    print(r'\vspace{6pt}')    
    print(codigo_latex)
    print(r'Fonte: ' + fonte)
    print(r'\end{table}')
    return

def gera_grafico_vies(df, coluna_interesse, titulo, linha_fina, fonte, nome_arquivo, limite_cor, limite_max_x,
                      intervalo_grade, cor_positivo, cor_negativo):    
    linhas = list(range(0,(len(df[coluna_interesse]) - 1)))
    df_modificado = df.loc[linhas,[coluna_interesse,'Frequência absoluta (ni)', 'Positivos (ni)', 'Negativos (ni)']].copy()
    # ordena os valores de forma decrescente
    df_modificado = df_modificado.sort_values(by = 'Frequência absoluta (ni)', ascending = True)
    # prepara as variáveis para criação do gráfico
    contagens_positivos = df_modificado['Positivos (ni)'].tolist()
    contagens_negativos = df_modificado['Negativos (ni)'].tolist()
    rotulos = df_modificado[coluna_interesse].tolist()    
    cinza = "#A2A2A2"
    # ajusta a altura da figura
    figura, eixo = plt.subplots(figsize = (7, 3.5))
    # ajusta os espaçamentos das barras e sua posição
    altura_barra = 0.30
    espacamento_barra = 0.05
    posicoes_barra = [i * 0.5 for i in range(len(rotulos))]
    # plota as barras empilhadas com a espessura e espaço entre elas ajustados
    for i, (rotulo, contagem_positivos, contagem_negativos, y_pos) in enumerate(zip(rotulos, contagens_positivos, contagens_negativos, 
                                                                                  posicoes_barra)):
        eixo.barh(y = y_pos, width = contagem_positivos, height = altura_barra, color = cor_positivo, edgecolor = 'black', 
                  label = 'Positivos')
        eixo.barh(y = y_pos, width = contagem_negativos, height = altura_barra, color = cor_negativo, edgecolor = 'black', 
                  label = 'Negativos', left = contagem_positivos)
    # configurações do eixo x
    eixo.xaxis.set_ticks(intervalo_grade) # define intervalo da grade do eixo x
    eixo.xaxis.set_ticklabels(intervalo_grade, size = 10, fontweight = 100)
    #eixo.xaxis.set_ticks([i * 10 for i in range(20)])  # define exibição de múltiplos de 10 no eixo x
    #eixo.xaxis.set_ticklabels([i * 10 for i in range(20)], size = 10, fontweight = 100)
    eixo.xaxis.set_tick_params(labelbottom = False, labeltop = True, length = 0)
    eixo.set_xlim(0, limite_max_x) # define o limite máximo do eixo x
    # configurações do gráfico
    eixo.set_axisbelow(True)
    eixo.grid(axis = "x", color = "#A8BAC4", lw = 1.2)
    eixo.spines["right"].set_visible(False)
    eixo.spines["top"].set_visible(False)
    eixo.spines["bottom"].set_visible(False)
    eixo.spines["left"].set_lw(1.5)
    eixo.spines["left"].set_capstyle("butt")
    eixo.yaxis.set_visible(False)
    # adiciona rótulos para os dados
    PAD = 0.3
    for rotulo, contagem_positivos, contagem_negativos, y_pos in zip(rotulos, contagens_positivos, contagens_negativos, posicoes_barra):
        x = 0
        cor = "white"
        efeitos = None
        if contagem_positivos + contagem_negativos < limite_cor:
            x = contagem_positivos + contagem_negativos
            cor = cor_positivo
            efeitos = [withStroke(linewidth = 6, foreground = "white")]
        eixo.text(x + PAD, y_pos, rotulo, color = cor, fontsize = 10, fontweight = "bold", va = "center", path_effects = efeitos)
    # ajusta o layout e adiciona título, linha fina e fonte
    figura.subplots_adjust(left = 0.005, right = 1, top = 0.8, bottom = 0.1)
    figura.text(0, 0.925, titulo, fontsize = 11, fontweight = "bold")
    figura.text(0, 0.875, linha_fina, fontsize = 9)
    figura.text(0, 0.06, fonte, color = cinza, fontsize = 9)
    # adiciona uma linha e um retângulo vermelhos no topo da figura
    figura.add_artist(lines.Line2D([0, 1], [1, 1], lw = 3, color = cor_negativo, solid_capstyle = "butt"))
    figura.add_artist(patches.Rectangle((0, 0.975), 0.05, 0.025, color = cor_negativo))
    # adiciona uma legenda
    eixo.legend(['Positivos', 'Negativos'], loc = 'lower right', fontsize = 9)
    # ajusta a cor de fundo
    figura.set_facecolor("white")
    # define diretório no qual o gráfico será salvo
    diretorio_atual = os.getcwd()
    subdiretorio = 'graficos'
    caminho_completo = os.path.join(diretorio_atual, subdiretorio, nome_arquivo)
    # salva o gráfico como uma imagem no diretório "graficos"
    plt.savefig(caminho_completo, dpi = 300, format = 'png')
    plt.show()
    return

def conta_registros(categoria):
  return categoria.sum()

def tabula_categorias(categorias, lista_frequencia, total):
    tabela_frequencia = pd.DataFrame({'Categoria': list(categorias)})
    tabela_frequencia['F.A.'] = lista_frequencia
    tabela_frequencia['F.R.'] = np.nan
    for registro in tabela_frequencia['F.R.']:
        tabela_frequencia['F.R.'] = (tabela_frequencia['F.A.']/total).round(3)
    return tabela_frequencia

def tabula_colunas(df_interesse, linhas, colunas, total):
    subconjunto = df_interesse.iloc[linhas, colunas].copy()
    frequencias = []
    for atributo in subconjunto:
        frequencias.append(conta_registros(subconjunto[atributo]))
    tabela_frequencias = tabula_categorias(subconjunto, frequencias, total)
    return tabela_frequencias
    
def agrupa_frequencias(subcategorias, tabela_frequencia, absoluta):
    fa_categoria = 0  
    for registro in subcategorias:
        fa_categoria +=  tabela_frequencia.at[registro, absoluta]        
    return fa_categoria

def tabula_macrocategorias(macrocategorias, absoluta, relativa):    
    agrupamento_itens = [4,5] # subcategorias da categoria "1.2. Agrupamento/Distinção de Itens"
    macrocategorias.at[3, absoluta] = agrupa_frequencias(agrupamento_itens, macrocategorias, absoluta)
    conducao = [2,3,6,7] # subcategorias da categoria "1. Condução"
    macrocategorias.at[1, absoluta] = agrupa_frequencias(conducao, macrocategorias, absoluta)
    brevidade = [10,11] # subcategorias da categoria "2.1. Brevidade"
    macrocategorias.at[9, absoluta] = agrupa_frequencias(brevidade, macrocategorias, absoluta)
    carga = [9,12] # subcategorias da categoria "2. Carga de Trabalho"
    macrocategorias.at[8, absoluta] = agrupa_frequencias(carga, macrocategorias, absoluta)
    controle = [14,15] # subcategorias da categoria "3. Controle Explícito"
    macrocategorias.at[13, absoluta] = agrupa_frequencias(controle, macrocategorias, absoluta)
    adaptabilidade = [17,18] # subcategorias da categoria "4. Adaptabilidade"
    macrocategorias.at[16, absoluta] = agrupa_frequencias(adaptabilidade, macrocategorias, absoluta)
    erros = [20,21,22] # subcategorias da categoria "5. Gestão de Erros"
    macrocategorias.at[19, absoluta] = agrupa_frequencias(erros, macrocategorias, absoluta)
    criterios_ergonomicos_usabilidade = [1,8,13,16,19,23,24,25] # macrocategorias dos "Critérios Ergonômicos de Usabilidade"
    macrocategorias.at[0, absoluta] = agrupa_frequencias(criterios_ergonomicos_usabilidade, macrocategorias, absoluta)
    qualidade_pragmatica = [28,29,30,31,32,33,34] # subcategorias da categoria "1. Qualidade Pragmática"
    macrocategorias.at[27, absoluta] = agrupa_frequencias(qualidade_pragmatica, macrocategorias, absoluta)
    identificacao = [37,38,39,40,41,42,43] # subcategorias da categoria "2.1. Identificação"
    macrocategorias.at[36, absoluta] = agrupa_frequencias(identificacao, macrocategorias, absoluta)
    estimulacao = [45,46,47,48,49,50,51] # subcategorias da categoria "2.2. Estimulação"
    macrocategorias.at[44, absoluta] = agrupa_frequencias(estimulacao, macrocategorias, absoluta)
    qualidade_hedonica = [36,44] # subcategorias da categoria "2. Qualidade Hedônica"
    macrocategorias.at[35, absoluta] = agrupa_frequencias(qualidade_hedonica, macrocategorias, absoluta)
    construtos_avaliativos = [53,54] # subcategorias da categoria "3. Construtos Avaliativos"
    macrocategorias.at[52, absoluta] = agrupa_frequencias(construtos_avaliativos, macrocategorias, absoluta)
    dimensoes_ux = [27,35,52] # macrocategorias das "Dimensões principais da user experience (UX)
    macrocategorias.at[26, absoluta] = agrupa_frequencias(dimensoes_ux, macrocategorias, absoluta)
    principios_ihd = [56,57,58] # macrocategorias dos "Princípios básicos da Interação Humano-Dados (IHD)"
    macrocategorias.at[55, absoluta] = agrupa_frequencias(principios_ihd, macrocategorias, absoluta)
    # totaliza as questões/problemas identificados a partir dos excertos/registos extraidos do teste de usabilidade
    metodos = [0,26,55]
    total_problemas = agrupa_frequencias(metodos, macrocategorias, absoluta)
    for registro in macrocategorias:
        macrocategorias[relativa] =  (macrocategorias[absoluta]/total_problemas).round(3)
    return total_problemas

def tabula_questoes(frequencia_geral, frequencia_positivos, frequencia_negativos, absoluta, relativa, coluna, linha_total):
    macrocategorias = frequencia_geral
    total_problemas = tabula_macrocategorias(macrocategorias, absoluta, relativa)
    macrocategorias_positivos = frequencia_positivos
    total_problemas_positivos = tabula_macrocategorias(macrocategorias_positivos, absoluta, relativa)
    macrocategorias_negativos = frequencia_negativos
    total_problemas_negativos = tabula_macrocategorias(macrocategorias_negativos, absoluta, relativa)
    consolidado = consolida_vies(macrocategorias, macrocategorias_positivos, macrocategorias_negativos, coluna, linha_total)  
    # corrige a totalização levando em consideração a hierarquia de categorias
    valores = [total_problemas, 1.0, total_problemas_positivos, 1.0, total_problemas_negativos, 1.0]
    consolidado.iloc[59, 1:] = valores
    return consolidado

def gera_grafico_categorias(df, absoluta, coluna_interesse, PAD, titulo, linha_fina, fonte, nome_arquivo, limite_cor, limite_max_x,
                            intervalo_grade, cor_ceu, cor_ux, cor_ihd):
    # ordena o dataFrame com base na coluna de frequência absoluta
    df = df.sort_values(by = absoluta, ascending = True)
    # prepara as variáveis
    rotulos = df[coluna_interesse].tolist()
    contagens = df[absoluta].tolist()
    cinza = "#A2A2A2"
    # ajusta a altura da figura
    figura, eixo = plt.subplots(figsize = (10, 6.8))
    # ajusta os espaçamentos das barras e sua posição
    altura_barra = 0.35
    espacamento_barra = 0.1
    posicoes_barra = [i * 0.5 for i in range(len(rotulos))]
    # plota as barras para CEU, UX e IHD com as cores definidas
    for rotulo, contagem, y_pos in zip(rotulos, contagens, posicoes_barra):
        if df.loc[df[coluna_interesse] == rotulo, 'Macro'].values[0] == 'CEU':
            eixo.barh(y = y_pos, width = contagem, height = altura_barra, color = cor_ceu, edgecolor = 'black', label = 'CEU')
        elif df.loc[df[coluna_interesse] == rotulo, 'Macro'].values[0] == 'UX':
            eixo.barh(y = y_pos, width = contagem, height = altura_barra, color=cor_ux, edgecolor = 'black', label = 'UX')
        elif df.loc[df[coluna_interesse] == rotulo, 'Macro'].values[0] == 'IHD':
            eixo.barh(y = y_pos, width = contagem, height = altura_barra, color=cor_ihd, edgecolor = 'black', label = 'IHD')
    # configurações do eixo x
    eixo.xaxis.set_ticks(intervalo_grade)
    eixo.xaxis.set_ticklabels(intervalo_grade, size = 10, fontweight = 100)
    eixo.xaxis.set_tick_params(labelbottom = False, labeltop = True, length = 0)
    eixo.set_xlim(0, limite_max_x)
    # configurações do gráfico
    eixo.set_axisbelow(True)
    eixo.grid(axis = "x", color = "#A8BAC4", lw = 1.2)
    eixo.spines["right"].set_visible(False)
    eixo.spines["top"].set_visible(False)
    eixo.spines["bottom"].set_visible(False)
    eixo.spines["left"].set_lw(1.5)
    eixo.spines["left"].set_capstyle("butt")
    eixo.yaxis.set_visible(False)
    # adiciona rótulos para os dados
    #PAD = 0.6
    for rotulo, contagem, y_pos in zip(rotulos, contagens, posicoes_barra):
        x = 0
        cor = "white"
        efeitos = None
        if contagem < limite_cor:
            x = contagem
            cor = "#6E6E6E"
            efeitos = [withStroke(linewidth = 6, foreground = "white")]
        eixo.text(x + PAD, y_pos, rotulo, color = cor, fontsize = 10, fontweight = "bold", va = "center", path_effects = efeitos)  
    # ajusta o layout e adiciona título, linha fina e fonte
    figura.subplots_adjust(left = 0.005, right = 1, top = 0.8, bottom = 0.1)
    figura.text(0, 0.925, titulo, fontsize = 15, fontweight = "bold")
    figura.text(0, 0.875, linha_fina, fontsize = 13)
    figura.text(0, 0.06, fonte, color = cinza, fontsize = 9)
    # adiciona uma linha e um retângulo rosa no topo da figura
    figura.add_artist(lines.Line2D([0, 1], [1, 1], lw = 3, color = cor_ceu, solid_capstyle = "butt"))
    figura.add_artist(patches.Rectangle((0, 0.975), 0.05, 0.025, color = cor_ceu))
    # adiciona uma legenda
    eixo.legend(handles=[mpatches.Patch(color=cor_ceu, label='Critérios Ergonômicos de Usabilidade'),
                          mpatches.Patch(color=cor_ux, label='Dimensões Principais da UX'),
                          mpatches.Patch(color=cor_ihd, label='Princípios Básicos da IHD')],loc='lower right', fontsize=9)
    # ajusta a cor de fundo
    figura.set_facecolor("white")
    # define diretório no qual o gráfico será salvo
    diretorio_atual = os.getcwd()
    subdiretorio = 'graficos'
    caminho_completo = os.path.join(diretorio_atual, subdiretorio, nome_arquivo)
    # salva o gráfico como uma imagem no diretório "graficos"
    plt.savefig(caminho_completo, dpi = 300, format = 'png')
    plt.show()
    return

def extratifica_tabela(tabela, indices, nome_coluna):
    consolidado_extratificado = pd.DataFrame()  
    consolidado_extratificado = tabela.loc[tabela.index.isin(indices)].copy()
    consolidado_extratificado.rename(columns={'Categoria': nome_coluna}, inplace = True)
    return consolidado_extratificado

def cria_esqueleto_arvore():
    colunas_arvore = ['Macrocategoria', 'ni', 'fi', 'Ni', 'Fi', 'Categoria','C (ni)', 'C (fi)', 'C (Ni)', 'C (Fi)', 'Subcategoria', 'S (ni)',
                      'S (fi)', 'S (Ni)', 'S (Fi)', 'Subtipo', 'Sb (ni)', 'Sb (fi)']
    arvore_indices = range(44)
    arvore_categorias = pd.DataFrame(columns = colunas_arvore, index = arvore_indices)
    arvore_categorias.loc[0:17,'Macrocategoria'] = ('A. Critérios Ergonômicos de Usabilidade')
    arvore_categorias.loc[0:4,'Categoria'] = ('A.1. Condução')
    arvore_categorias.loc[0, 'Subcategoria'] = ('A.1.1. Presteza')
    arvore_categorias.loc[1:2,'Subcategoria'] = ('A.1.2. Agrupamento/Distinção de Itens')
    arvore_categorias.loc[1,'Subtipo'] = ('A.1.2.1. Agrupamento de Itens - Localização')
    arvore_categorias.loc[2,'Subtipo'] = ('A.1.2.2. Agrupamento de Itens - Formato')
    arvore_categorias.loc[3,'Subcategoria'] = ('A.1.3. Feedback Imediato')
    arvore_categorias.loc[4,'Subcategoria'] = ('A.1.4. Legibilidade')
    arvore_categorias.loc[5:7,'Categoria'] = ('A.2. Carga de Trabalho')
    arvore_categorias.loc[5:6,'Subcategoria'] =('A.2.1. Brevidade')
    arvore_categorias.loc[5,'Subtipo'] =('A.2.1.1. Brevidade - Concisão')
    arvore_categorias.loc[6,'Subtipo'] =('A.2.1.1. Brevidade - Ações Mínimas')
    arvore_categorias.loc[7,'Subcategoria'] =('A.2.2. Densidade Informacional')
    arvore_categorias.loc[8:9,'Categoria'] = ('A.3. Controle Explícito')
    arvore_categorias.loc[8,'Subcategoria'] =('A.3.1. Ações Explícitas')
    arvore_categorias.loc[9,'Subcategoria'] =('A.3.2. Controle do Usuário')
    arvore_categorias.loc[10:11,'Categoria'] = ('A.4. Adaptabilidade')
    arvore_categorias.loc[10,'Subcategoria'] =('A.4.1. Flexibilidade')
    arvore_categorias.loc[11,'Subcategoria'] =('A.4.2. Experiência do Usuário')
    arvore_categorias.loc[12:14,'Categoria'] = ('A.5. Gestão de Erros')
    arvore_categorias.loc[12,'Subcategoria'] =('A.5.1. Proteção contra Erros')
    arvore_categorias.loc[13,'Subcategoria'] =('A.5.2. Qualidade das Mensagens de Erros')
    arvore_categorias.loc[14,'Subcategoria'] =('A.5.3. Correção Erros')
    arvore_categorias.loc[15,'Categoria'] = ('A.6. Coerência/Consistência (Homogeneidade)')
    arvore_categorias.loc[16,'Categoria'] = ('A.7. Significado dos Códigos e Denominações')
    arvore_categorias.loc[17,'Categoria'] = ('A.8. Compatibilidade')
    arvore_categorias.loc[18:41,'Macrocategoria'] = ('B. Dimensões principais da user experience (UX)')
    arvore_categorias.loc[18:24,'Categoria'] =('B.1. Qualidade pragmática')
    arvore_categorias.loc[18,'Subcategoria'] =('B.1.1. Humanidade')
    arvore_categorias.loc[19,'Subcategoria'] =('B.1.2. Simplicidade')
    arvore_categorias.loc[20,'Subcategoria'] =('B.1.3. Praticidade')
    arvore_categorias.loc[21,'Subcategoria'] =('B.1.4. Objetividade')
    arvore_categorias.loc[22,'Subcategoria'] =('B.1.5. Previsibilidade')
    arvore_categorias.loc[23,'Subcategoria'] =('B.1.6. Clareza')
    arvore_categorias.loc[24,'Subcategoria'] =('B.1.7. Controle')
    arvore_categorias.loc[25:38,'Categoria'] =('B.2. Qualidade hedônica')
    arvore_categorias.loc[25:31,'Subcategoria'] =('B.2.1. Identificação')
    arvore_categorias.loc[25,'Subtipo'] = ('B.2.1.1. Integração')
    arvore_categorias.loc[26,'Subtipo'] = ('B.2.1.2. Profissionalismo')
    arvore_categorias.loc[27,'Subtipo'] = ('B.2.1.3. Classe')
    arvore_categorias.loc[28,'Subtipo'] = ('B.2.1.4. Valor')
    arvore_categorias.loc[29,'Subtipo'] = ('B.2.1.5. Inclusão')
    arvore_categorias.loc[30,'Subtipo'] = ('B.2.1.6. Socialização')
    arvore_categorias.loc[31,'Subtipo'] = ('B.2.1.7. Apresentação')
    arvore_categorias.loc[32:38,'Subcategoria'] =('B.2.2. Estimulação')
    arvore_categorias.loc[32,'Subtipo'] = ('B.2.2.1. Originalidade')
    arvore_categorias.loc[33,'Subtipo'] = ('B.2.2.2. Criatividade')
    arvore_categorias.loc[34,'Subtipo'] = ('B.2.2.3. Coragem')
    arvore_categorias.loc[35,'Subtipo'] = ('B.2.2.4. Inovação')
    arvore_categorias.loc[36,'Subtipo'] = ('B.2.2.5. Excitação')
    arvore_categorias.loc[37,'Subtipo'] = ('B.2.2.6. Desafio')
    arvore_categorias.loc[38,'Subtipo'] = ('B.2.2.7. Novidade')
    arvore_categorias.loc[39:40,'Categoria'] =('B.3. Construtos avaliativos')
    arvore_categorias.loc[39,'Subcategoria'] =('B.3.1. Beleza')
    arvore_categorias.loc[40,'Subcategoria'] =('B.3.2. Goodness')
    arvore_categorias.loc[41:43,'Macrocategoria'] = ('C. Princípios básicos da Interação Humano-Dados (IHD)')
    arvore_categorias.loc[41,'Categoria'] =('C.1. Agência')
    arvore_categorias.loc[42,'Categoria'] =('C.2. Legibilidade')
    arvore_categorias.loc[43,'Categoria'] =('C.3. Negociabilidade')
    arvore_categorias.loc[44,'Macrocategoria'] = ('Total')
    arvore_categorias.loc[44,'Categoria'] = ('Subtotal')
    arvore_categorias.loc[44,'Subcategoria'] = ('Subtotal')
    arvore_categorias.loc[44,'Subtipo'] = ('Subtotal')
    colunas_frequencia_relativa = ['fi', 'Fi', 'C (fi)', 'C (Fi)', 'S (fi)', 'S (Fi)', 'Sb (fi)']
    for coluna in colunas_frequencia_relativa:
        arvore_categorias[coluna] = arvore_categorias[coluna].astype(float)
    return arvore_categorias

def aplica_mapeamento(mapeamento, coluna_destino, arvore, df_original, coluna_origem):
    for destino, origem in mapeamento.items():
        arvore.loc[destino, coluna_destino] = df_original.loc[origem, coluna_origem]
    return

def popula_frequencias_absolutas(arvore_categorias, df_original, coluna_origem):    
    # dicionário que mapeia índices de destino de subtipos em 'arvore' aos índices de origem em 'consolidado_macrocategorias'
    mapeamento_subtipos = {1: 4, 2: 5,
                           5: 10, 6: 11,
                           25: 37, 26: 38, 27: 39, 28: 40, 29: 41, 30: 42, 31: 43,
                           32: 45, 33: 46, 34: 47, 35: 48, 36: 49, 37: 50, 38: 51
                          }    
    # dicionário que mapeia índices de destino de subcategorias sem subtipos em 'arvore' aos índices de origem em 'consolidado_macrocategorias'
    mapeamento_subcategorias = {0: 2,
                                3: 6, 4: 7,
                                7: 12, 8: 14, 9: 15, 10: 17, 11: 18, 12: 20, 13: 21, 14: 22,
                                18: 28, 19: 29, 20: 30, 21: 31, 22: 32, 23: 33, 24: 34,
                                39: 53, 40: 54
                               }    
    # dicionário que mapeia índices de destino de categorias sem subcategorias em 'arvore' aos índices de origem em 'consolidado_macrocategorias'
    mapeamento_categorias = {15: 23, 16: 24, 17: 25,
                             41: 56, 42: 57, 43: 58
                            }
    # popula as colunas de frequência absoluta da árvore a partir dos mapeamentos
    aplica_mapeamento(mapeamento_subtipos, 'Sb (ni)', arvore_categorias, df_original, coluna_origem)
    aplica_mapeamento(mapeamento_subcategorias, 'S (ni)', arvore_categorias, df_original, coluna_origem)
    aplica_mapeamento(mapeamento_categorias, 'C (ni)', arvore_categorias, df_original, coluna_origem)
    return

def trata_nulos(arvore_categorias): 
    # lista de colunas nas quais o nulo será substituído por zero
    colunas_numericas = ['Sb (ni)', 'Sb (fi)', 'S (ni)', 'S (fi)', 'S (Ni)', 'S (Fi)', 'C (ni)', 'C (fi)', 'C (Ni)', 'C (Fi)',
                         'ni', 'fi', 'Ni', 'Fi']
    # trata nulos susbstindo NaN por zero
    arvore_categorias[colunas_numericas] = arvore_categorias[colunas_numericas].fillna(0)
    return
    
def replica_valores(linha):
    if linha['Sb (ni)'] != 0:
        linha['ni'] = linha['Sb (ni)']
        linha['C (ni)'] = linha['Sb (ni)']
        linha['S (ni)'] = linha['Sb (ni)']
    elif linha['S (ni)'] != 0:
        linha['C (ni)'] = linha['S (ni)']
        linha['ni'] = linha['S (ni)']
    else:
        linha['ni'] = linha['C (ni)']
    return linha

def calcula_totais(arvore_categorias):
    colunas_ni = ['ni', 'C (ni)', 'S (ni)', 'Sb (ni)']
    soma = 0
    for coluna in colunas_ni:
        soma = arvore_categorias[coluna].sum()
        arvore_categorias.loc[44, coluna] = soma
    return
    
def calcula_frequencias_relativas(arvore_categorias):
    for registro in arvore_categorias:
        arvore_categorias['fi'] = (arvore_categorias['ni']/arvore_categorias.loc[44,'ni']).round(3)
        arvore_categorias['C (fi)'] = (arvore_categorias['C (ni)']/arvore_categorias.loc[44,'C (ni)']).round(3)
        arvore_categorias['S (fi)'] = (arvore_categorias['S (ni)']/arvore_categorias.loc[44,'S (ni)']).round(3)
        arvore_categorias['Sb (fi)'] = (arvore_categorias['Sb (ni)']/arvore_categorias.loc[44,'Sb (ni)']).round(2)    
    return

def soma_frequencias_niveis(arvore_categorias, indices_finais, Ni, Fi):
    soma_ni = 0
    soma_fi = 0
    for indice in indices_finais:
        soma_ni += arvore_categorias.loc[indice, Ni]
        soma_fi += arvore_categorias.loc[indice, Fi]
    arvore_categorias.loc[44, Ni] = soma_ni
    arvore_categorias.loc[44, Fi] = soma_fi
    return
    
def calcula_frequencias_acumuladas(arvore_categorias):
    # indica índices iniciais das subcategorias, categorias e macrocategorias 
    iniciais_subcategorias = [0,1,3,4,5,7,8,9,10,11,12,13,14,18,19,20,21,22,23,24,25,32,39,40]
    iniciais_categorias = [0,5,8,10,12,15,16,17,18,25,39,41,42,43]
    iniciais_macrocategorias = [0,18,41]
    # popula valores iniciais de frequência acumulada (Ni) e frequência relativa acumulada (Fi)
    for indice in iniciais_subcategorias:
        arvore_categorias.loc[indice,'S (Ni)'] = arvore_categorias.loc[indice,'S (ni)']
        arvore_categorias.loc[indice,'S (Fi)'] = arvore_categorias.loc[indice,'S (fi)']  
    for indice in iniciais_categorias:
        arvore_categorias.loc[indice,'C (Ni)'] = arvore_categorias.loc[indice,'C (ni)']
        arvore_categorias.loc[indice,'C (Fi)'] = arvore_categorias.loc[indice,'C (fi)']        
    for indice in iniciais_macrocategorias:
        arvore_categorias.loc[indice,'Ni'] = arvore_categorias.loc[indice,'ni']
        arvore_categorias.loc[indice,'Fi'] = arvore_categorias.loc[indice,'fi']
    # dicionário com os intervalos para cada subcategoria
    intervalos_subcategorias = {1: [2],
                                2: [6],
                                3: list(range(26, 32)),
                                4: list(range(33, 39)),
                               }
    # dicionário com os intervalos para cada categoria
    intervalos_categorias = {1: list(range(1,5)),
                             2: list(range(6,8)),
                             3: [9],
                             4: [11],
                             5: list(range(13,15)),
                             6: list(range(19,25)),
                             7: list(range(26,39)),
                             8: [40]
                            }
    # dicionário com os intervalos para cada macrocategoria
    intervalos_macrocategorias = {1: list(range(1,18)),
                                  2: list(range(19,41)),
                                  3: list(range(42,44))
                                 }
    #  popula demais valores de frequência acumulada (Ni) e frequência relativa acumulada (Fi) considerando os níveis hierárquicos
    for subcategoria, intervalo in intervalos_subcategorias.items():
        for indice in intervalo:
            arvore_categorias.loc[indice, 'S (Ni)'] = arvore_categorias.loc[indice, 'S (ni)'] + arvore_categorias.loc[indice - 1, 'S (Ni)']
            arvore_categorias.loc[indice, 'S (Fi)'] = arvore_categorias.loc[indice, 'S (fi)'] + arvore_categorias.loc[indice - 1, 'S (Fi)']
    for categoria, intervalo in intervalos_categorias.items():
        for indice in intervalo:
            arvore_categorias.loc[indice, 'C (Ni)'] = arvore_categorias.loc[indice, 'C (ni)'] + arvore_categorias.loc[indice - 1, 'C (Ni)']
            arvore_categorias.loc[indice, 'C (Fi)'] = arvore_categorias.loc[indice, 'C (fi)'] + arvore_categorias.loc[indice - 1, 'C (Fi)']
    for macrocategoria, intervalo in intervalos_macrocategorias.items():
        for indice in intervalo:
            arvore_categorias.loc[indice, 'Ni'] = arvore_categorias.loc[indice, 'ni'] + arvore_categorias.loc[indice - 1, 'Ni']
            arvore_categorias.loc[indice, 'Fi'] = arvore_categorias.loc[indice, 'fi'] + arvore_categorias.loc[indice - 1, 'Fi']
    # indica índices finais das subcategorias, categorias e macrocategorias 
    finais_subcategorias = [0,2,3,4,6,7,8,9,10,11,12,13,14,18,19,20,21,22,23,24,31,38,39,40]
    finais_categorias = [4,7,9,11,14,15,16,17,24,38,40,41,42,43]
    finais_macrocategorias = [17,40,43]
    # calcula totais considerando os níveis hierárquicos
    soma_frequencias_niveis(arvore_categorias, finais_subcategorias, 'S (Ni)', 'S (Fi)')
    soma_frequencias_niveis(arvore_categorias, finais_categorias, 'C (Ni)', 'C (Fi)')
    soma_frequencias_niveis(arvore_categorias, finais_macrocategorias, 'Ni', 'Fi')        
    return

def cria_arvore(consolidado_macrocategorias, ni):  
    arvore = cria_esqueleto_arvore()
    # preenche frequências absolutas iniciais (nos nós folhas) da árvore
    popula_frequencias_absolutas(arvore, consolidado_macrocategorias, ni)
    # trata valores nulos
    trata_nulos(arvore)
    # replica valores de frequência para níveis superiores da árvore
    arvore = arvore.apply(replica_valores, axis = 1)
    # calcula total e subtotais das frequências absolutas
    calcula_totais(arvore)
    # calcula frequências relativas (fi) em relação ao nível categórico
    calcula_frequencias_relativas(arvore)
    # calcula frequências acumuladas absolutas (Ni) e relativas (Fi) considerando níveis categóricos
    calcula_frequencias_acumuladas(arvore)
    return arvore
    
def cria_nuvem(texto, lista_stopwords, mascara, cores, nome_arquivo):
    # define o gradiente de cores da nuvem de palavras
    gradiente = LinearSegmentedColormap.from_list("mycmap", cores)
    # inicializa a nuvem de palavras
    nuvem = WordCloud(stopwords = lista_stopwords,
                      mask = mascara, # imagem utilizada
                      background_color = 'white', # cor de fundo
                      width = 1500, # largura
                      height = 750, # altura
                      contour_width = 1, # espessura do contorno
                      contour_color = 'purple', # cor do contorno
                      colormap = gradiente
                     )
    # gera a nuvem de palavras a partir do texto
    nuvem.generate(texto)
    # cria visualização
    plt.figure(figsize = (20, 15), facecolor = 'k') # tamanho do gráfico
    plt.imshow(nuvem, interpolation = 'bilinear') # plotagem da nuvem de palavras
    plt.axis('off') # remove as bordas
    # define diretório no qual o gráfico será salvo
    diretorio_atual = os.getcwd()
    subdiretorio = 'graficos'
    caminho_completo = os.path.join(diretorio_atual, subdiretorio, nome_arquivo)
    # salva o gráfico como uma imagem no diretório "graficos"
    plt.savefig(caminho_completo, dpi = 300, format = 'png')
    plt.show() # mostra a nuvem de palavras
    return

def anota_heatmap(data, fmt, tamanho):
    cores_texto =["black", "white"]
    threshold = 0.5
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            valor = data.iloc[i, j]
            cor = cores_texto[1] if abs(valor) > threshold else cores_texto[0]
            plt.text(j + 0.5, i + 0.5, format(valor, fmt), fontsize = tamanho, ha = "center", va = "center", color = cor)            
    return

# %% [markdown]
# ## **Leitura e preparação dos dados**

# %%
#paineis_covid = pd.read_excel("/home/marisa/Documentos/acadêmico/UFPR/TCC/usabilidade_ux_paineis_covid/dados/experimento_paineis_covid.xlsx", engine = "openpyxl")

# %%
# lê e armazena os resultados dos testes de usabilidade
paineis_covid = pd.read_excel("/home/marisa/Documentos/acadêmico/UFPR/TCC/usabilidade_ux_paineis_covid/dados/experimento_paineis_covid_teste.xlsx", 
                              sheet_name = "tabulacao_macro", engine = "openpyxl")
# lê e armazena os resultados do RGT
resultados_rgt = pd.read_excel("/home/marisa/Documentos/acadêmico/UFPR/TCC/usabilidade_ux_paineis_covid/dados/experimento_paineis_covid_teste.xlsx", 
                              sheet_name = "tabulacao_rgt_categorizacao", engine = "openpyxl")

# %% [markdown]
# ### **Criação de subconjuntos de dados**

# %%
# cria subconjuntos de registros positivos e negativos
positivos = paineis_covid.query("Viés == 'Positivo'")
negativos = paineis_covid.query("Viés == 'Negativo'")

# cria subconjuntos de registros relacionados ao painel Brasil.io (iniciativa voluntária)
brasil_io = paineis_covid.query("Painel == 'Brasil.io (iniciativa voluntária)'")
brasil_io_positivos = positivos.query("Painel == 'Brasil.io (iniciativa voluntária)'")
brasil_io_negativos = negativos.query("Painel == 'Brasil.io (iniciativa voluntária)'")

# cria subconjuntos de registros relacionados ao painel Coronavírus Brasil (Ministério da Saúde)
coronavirus_brasil = paineis_covid.query("Painel == 'Coronavírus Brasil (Ministério da Saúde)'")
coronavirus_brasil_positivos = positivos.query("Painel == 'Coronavírus Brasil (Ministério da Saúde)'")
coronavirus_brasil_negativos = negativos.query("Painel == 'Coronavírus Brasil (Ministério da Saúde)'")

# cria subconjuntos de registros relacionados ao painel MonitoraCovid-19 (Fiocruz)
monitora_covid = paineis_covid.query("Painel == 'MonitoraCovid-19 (Fiocruz)'")
monitora_covid_positivos = positivos.query("Painel == 'MonitoraCovid-19 (Fiocruz)'")
monitora_covid_negativos = negativos.query("Painel == 'MonitoraCovid-19 (Fiocruz)'")

# cria subconjuntos de registros relacionados ao painel Painel Nacional: Covid-19 (CONASS)
painel_nacional = paineis_covid.query("Painel == 'Painel Nacional: Covid-19 (CONASS)'")
painel_nacional_positivos = positivos.query("Painel == 'Painel Nacional: Covid-19 (CONASS)'")
painel_nacional_negativos = negativos.query("Painel == 'Painel Nacional: Covid-19 (CONASS)'")

# %% [markdown]
# ## **Tabulação inicial**

# %% [markdown]
# ### **Tabulação geral por registros analisados**

# %%
# registros analisados por viés
total_registros = len(paineis_covid.index)
frequencia_vies = tabula(paineis_covid["Viés"], total_registros)
display(frequencia_vies)
# Out:
#        Viés  F.A.   F.R.
# 0  Negativo    86  0.735
# 1  Positivo    31  0.265

# %%
# registros analisados por usuário e por viés
consolidado_usuarios = cria_tabela_consolidada(paineis_covid, total_registros, positivos, negativos, 'Usuário', 3)
consolidado_usuarios['Usuário'] = {0: 'ID 3', 1: 'ID 1', 2: 'ID 2', 3: 'Total'}
display(consolidado_usuarios)
# Out:
# /tmp/ipykernel_40821/1389229705.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Total' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   consolidado.loc[linha, coluna] = ('Total')
#   Usuário  Frequência absoluta (ni)  Frequência relativa (fi)  Positivos (ni)  \
# 0    ID 3                        57                     0.487              17
# 1    ID 1                        33                     0.282               7
# 2    ID 2                        27                     0.231               7
# 3   Total                       117                     1.000              31
#
#    Positivos (fi)  Negativos (ni)  Negativos (fi)
# 0           0.548              40           0.465
# 1           0.226              26           0.302
# 2           0.226              20           0.233
# 3           1.000              86           1.000

# %%
# cria tabela de frequência para exibição no LateX, considerando as frequências relativas de positivos e negativos por registro (linha)
tabela_usuario = cria_tabela_impressao(consolidado_usuarios, 'Registros (ni)', 3)
tabela_usuario = tabela_usuario.sort_values(by = 'Usuário', ascending = True)
display(tabela_usuario)
# Out:
#   Usuário  Registros (ni)  Frequência relativa (fi)  Positivos (ni)  \
# 1    ID 1              33                      0.28               7
# 2    ID 2              27                      0.23               7
# 0    ID 3              57                      0.49              17
#
#    Positivos (fi)  Negativos (ni)  Negativos (fi)
# 1            0.21              26            0.79
# 2            0.26              20            0.74
# 0            0.30              40            0.70

# %%
# gera o código em LateX da tabela acima
tabela_usuario.rename(columns = {'Usuário': r'\makecell{\textbf{Usuário}}', 
                                 'Registros (ni)': r'\makecell{\textbf{Registros (n\textsubscript{i})}}',
                                 'Frequência relativa (fi)': r'\makecell{\shortstack{\textbf{Frequência} \\ \textbf{(relativa f\textsubscript{i})}}}',
                                 'Positivos (ni)': r'\makecell{\textbf{Positivos (n\textsubscript{i})}} ',
                                 'Positivos (fi)': r'\makecell{\textbf{Positivos (f\textsubscript{i})}}',
                                 'Negativos (ni)': r'\makecell{\textbf{Negativos (n\textsubscript{i})}}',	
                                 'Negativos (fi)': r'\makecell{\textbf{Negativos (f\textsubscript{i})}}'}, 
                      inplace=True)

titulo = 'Distribuição dos registros analisados por usuário e viés.'
tag = 'tab:geral_usuario_vies'
fonte = 'elaborada pela autora (2023).'

gera_tabela_latex(tabela_usuario, titulo, tag, fonte)
# Out:
# \begin{table}[!htp]
# \centering
# \caption{Distribuição dos registros analisados por usuário e viés.}
# \label{tab:geral_usuario_vies}
# \footnotesize
# \renewcommand{\arraystretch}{1.5}
# \vspace{6pt}
# \begin{tabular}{lrlrlrl}
# \toprule
# \makecell{\textbf{Usuário}} & \makecell{\textbf{Registros (n\textsubscript{i})}} & \makecell{\shortstack{\textbf{Frequência} \\ \textbf{(relativa f\textsubscript{i})}}} & \makecell{\textbf{Positivos (n\textsubscript{i})}}  & \makecell{\textbf{Positivos (f\textsubscript{i})}} & \makecell{\textbf{Negativos (n\textsubscript{i})}} & \makecell{\textbf{Negativos (f\textsubscript{i})}} \\
# \midrule
# ID 1 & 33 & 0,28 & 7 & 0,21 & 26 & 0,79 \\
# ID 2 & 27 & 0,23 & 7 & 0,26 & 20 & 0,74 \\
# ID 3 & 57 & 0,49 & 17 & 0,30 & 40 & 0,70 \\
# \bottomrule
# \end{tabular}
#
# Fonte: elaborada pela autora (2023).
# \end{table}

# %%
# gera gráfico de registros analisados por usuário e por viés

# define cores personalizadas para o gráfico
cor_positivo = "#405A78"
cor_negativo = "#C2323C"
# define parâmetros de informação
titulo = "Registros por usuário e viés"
linha_fina = "Número de registros (excertos) analisados"
fonte = "Fonte: a autora"
nome_arquivo = 'usuario_vies_geral.png'
limite_cor = 8
# define intervalo de grande e o limite máximo do eixo x
intervalo = [i * 10 for i in range(20)] # define exibição de múltiplos de 10 no eixo x
limite_max_x = 63
gera_grafico_vies(consolidado_usuarios, 'Usuário', titulo, linha_fina, fonte, nome_arquivo, limite_cor, limite_max_x,
                  intervalo, cor_positivo, cor_negativo)

# %%
# registros analisados por painel e por viés
consolidado_paineis = cria_tabela_consolidada(paineis_covid, total_registros, positivos, negativos, 'Painel', 4)
display(consolidado_paineis)
# Out:
#                                      Painel  Frequência absoluta (ni)  \
# 0                MonitoraCovid-19 (Fiocruz)                        34
# 1  Coronavírus Brasil (Ministério da Saúde)                        33
# 2         Brasil.io (iniciativa voluntária)                        31
# 3        Painel Nacional: Covid-19 (CONASS)                        19
# 4                                     Total                       117
#
#    Frequência relativa (fi)  Positivos (ni)  Positivos (fi)  Negativos (ni)  \
# 0                     0.291              15           0.484              19
# 1                     0.282               2           0.065              31
# 2                     0.265               6           0.194              25
# 3                     0.162               8           0.258              11
# 4                     1.000              31           1.001              86
#
#    Negativos (fi)
# 0           0.221
# 1           0.360
# 2           0.291
# ...

# %%
# cria tabela de frequência para exibição no LateX, considerando as frequências relativas de positivos e negativos por registro (linha)
consolidado_paineis['Painel'] = {0: 'MonitoraCovid-19', 1: 'Coronavírus Brasil', 2: 'Brasil.io', 3: 'Painel Nacional: Covid-19',
                                4: 'Total'}
tabela_painel = cria_tabela_impressao(consolidado_paineis, 'Registros (ni)', 4)
display(tabela_painel)
# Out:
#                       Painel  Registros (ni)  Frequência relativa (fi)  \
# 0           MonitoraCovid-19              34                      0.29
# 1         Coronavírus Brasil              33                      0.28
# 2                  Brasil.io              31                      0.26
# 3  Painel Nacional: Covid-19              19                      0.16
#
#    Positivos (ni)  Positivos (fi)  Negativos (ni)  Negativos (fi)
# 0              15            0.44              19            0.56
# 1               2            0.06              31            0.94
# 2               6            0.19              25            0.81
# 3               8            0.42              11            0.58

# %%
# gera o código em LateX da tabela acima
tabela_painel.rename(columns = {'Painel': r'\makecell{\textbf{Painel}}', 
                                 'Registros (ni)': r'\makecell{\textbf{Registros (n\textsubscript{i})}}',
                                 'Frequência relativa (fi)': r'\makecell{\shortstack{\textbf{Frequência} \\ \textbf{(relativa f\textsubscript{i})}}}',
                                 'Positivos (ni)': r'\makecell{\textbf{Positivos (n\textsubscript{i})}} ',
                                 'Positivos (fi)': r'\makecell{\textbf{Positivos (f\textsubscript{i})}}',
                                 'Negativos (ni)': r'\makecell{\textbf{Negativos (n\textsubscript{i})}}',	
                                 'Negativos (fi)': r'\makecell{\textbf{Negativos (f\textsubscript{i})}}'}, 
                      inplace=True)

titulo = 'Distribuição dos registros analisados por painel e viés.'
tag = 'tab:geral_painel_vies'
fonte = 'elaborada pela autora (2023).'

gera_tabela_latex(tabela_painel, titulo, tag, fonte)
# Out:
# \begin{table}[!htp]
# \centering
# \caption{Distribuição dos registros analisados por painel e viés.}
# \label{tab:geral_painel_vies}
# \footnotesize
# \renewcommand{\arraystretch}{1.5}
# \vspace{6pt}
# \begin{tabular}{lrlrlrl}
# \toprule
# \makecell{\textbf{Painel}} & \makecell{\textbf{Registros (n\textsubscript{i})}} & \makecell{\shortstack{\textbf{Frequência} \\ \textbf{(relativa f\textsubscript{i})}}} & \makecell{\textbf{Positivos (n\textsubscript{i})}}  & \makecell{\textbf{Positivos (f\textsubscript{i})}} & \makecell{\textbf{Negativos (n\textsubscript{i})}} & \makecell{\textbf{Negativos (f\textsubscript{i})}} \\
# \midrule
# MonitoraCovid-19 & 34 & 0,29 & 15 & 0,44 & 19 & 0,56 \\
# Coronavírus Brasil & 33 & 0,28 & 2 & 0,06 & 31 & 0,94 \\
# Brasil.io & 31 & 0,26 & 6 & 0,19 & 25 & 0,81 \\
# Painel Nacional: Covid-19 & 19 & 0,16 & 8 & 0,42 & 11 & 0,58 \\
# \bottomrule
# \end{tabular}
#
# Fonte: elaborada pela autora (2023).
# \end{table}

# %%
# gera gráfico de registros analisados por usuário e por viés
consolidado_paineis['Painel'] = {0: 'MonitoraCovid-19', 1: 'Coronavírus Brasil', 2: 'Brasil.io', 3: 'Painel Nacional: Covid-19',
                                4: 'Total'}
titulo = "Registros por painel e viés"
linha_fina = "Número de registros (excertos) analisados"
fonte = "Fonte: a autora"
nome_arquivo = 'painel_vies_geral.png'
limite_cor = 8
intervalo = [i * 10 for i in range(20)] # define exibição de múltiplos de 10 no eixo x
limite_max_x = 43
gera_grafico_vies(consolidado_paineis, 'Painel', titulo, linha_fina, fonte, nome_arquivo, limite_cor, limite_max_x,
                  intervalo, cor_positivo, cor_negativo)

# %%
# registros analisados por fonte e por viés (OBS.: fazer mais uma função que conte apenas uma, duas, três  etc fontes e quais)
linhas_recorte = range(0,117)
colunas_fontes = range(5,8)
frequencia_fontes_registros = tabula_colunas(paineis_covid, linhas_recorte, colunas_fontes, total_registros)
display(frequencia_fontes_registros)
# Out:
#                    Categoria  F.A.   F.R.
# 0             Thinking aloud    82  0.701
# 1  Registro escrito do teste    79  0.675
# 2                 Observação    32  0.274

# %% [markdown]
# ## **Tabulação categorias**

# %% [markdown]
# ### **Tabulação geral das categorias por registros analisados**

# %%
# índices das categorias por nível hierárquico de classificação
indices_macrocategorias = [0,26,55,59]
indices_categorias = [1,8,13,16,19,23,24,25,27,35,52,56,57,58,59]
indices_subcategorias = [2,3,6,7,9,12,14,15,17,18,20,21,22,28,29,30,31,32,33,34,36,44,53,54]
indices_subtipos = [4,5,10,11,37,38,39,40,41,42,43,45,46,47,48,49,50,51]

# %%
# registros analisados por categoria
colunas_categorias = range(8, 67)
frequencia_categorias = tabula_colunas(paineis_covid, linhas_recorte, colunas_categorias, total_registros)
display(frequencia_categorias)
# Out:
#                                             Categoria  F.A.   F.R.
# 0       A. Critérios Ergonômicos de Usabilidade (CEU)   110  0.940
# 1                                       A.1. Condução    27  0.231
# 2                                     A.1.1. Presteza    12  0.103
# 3               A.1.2. Agrupamento/Distinção de Itens     2  0.017
# 4         A.1.2.1. Agrupamento de Itens - Localização     0  0.000
# 5              A.1.2.2 Agrupamento de Itens - Formato     2  0.017
# 6                            A.1.3. Feedback Imediato     9  0.077
# 7                                 A.1.4. Legibilidade     4  0.034
# 8                              A.2. Carga de Trabalho    52  0.444
# 9                                    A.2.1. Brevidade    16  0.137
# 10                      A.2.1.1. Brevidade - Concisão     0  0.000
# 11                 A.2.1.1. Brevidade - Ações Mínimas    16  0.137
# 12                     A.2.2. Densidade Informacional    36  0.308
# ...

# %% [markdown]
# ### **Tabulação geral das categorias por questões encontradas nos registros e categorizadas**

# %%
# registros analisados por viés, em dataframes intermediários, para construção da tabulação por questões encontradas
recorte_positivos = range(0,31)
recorte_negativos = range(0,86)
frequencia_categorias_positivos = tabula_colunas(positivos, recorte_positivos, colunas_categorias, total_registros)
frequencia_categorias_negativos = tabula_colunas(negativos, recorte_negativos, colunas_categorias, total_registros)
# tabulação das questões encontradas nos registros e categorizadas
# atenção: um registro pode ter sido categorizado em mais de uma questão e há quatro níveis hierárquicos de categorias
consolidado_macrocategorias = tabula_questoes(frequencia_categorias, frequencia_categorias_positivos, 
                                              frequencia_categorias_negativos, 'F.A.', 'F.R.', 'Categoria', 59)
display(consolidado_macrocategorias)
# Out:
#                                             Categoria  \
# 0       A. Critérios Ergonômicos de Usabilidade (CEU)
# 1                                       A.1. Condução
# 2                                     A.1.1. Presteza
# 3               A.1.2. Agrupamento/Distinção de Itens
# 4         A.1.2.1. Agrupamento de Itens - Localização
# 5              A.1.2.2 Agrupamento de Itens - Formato
# 6                            A.1.3. Feedback Imediato
# 7                                 A.1.4. Legibilidade
# 8                              A.2. Carga de Trabalho
# 9                                    A.2.1. Brevidade
# 10                      A.2.1.1. Brevidade - Concisão
# 11                 A.2.1.1. Brevidade - Ações Mínimas
# 12                     A.2.2. Densidade Informacional
# 13                            A.3. Controle Explícito
# 14                            A.3.1. Ações Explícitas
# 15                         A.3.2. Controle do Usuário
# ...

# %%
# registros analisados por viés, em dataframes intermediários, para construção da tabulação por questões encontradas

# gera tabela resumida apenas com as macrocategorias/ métodos usados na análise
consolidado_metodos = extratifica_tabela(consolidado_macrocategorias, indices_macrocategorias, 'Método/Macrocategoria')
# gera tabela resumida apenas com as categorias (segundo nível de classificação)
consolidado_categorias = extratifica_tabela(consolidado_macrocategorias, indices_categorias, 'Categoria')
# gera tabela resumida apenas com as subcategorias (terceiro nível de classificação)
consolidado_subcategorias = extratifica_tabela(consolidado_macrocategorias, indices_subcategorias, 'Subcategoria')
# gera tabela resumida apenas com os subtipos (quarto nível de classificação)
consolidado_subtipos = extratifica_tabela(consolidado_macrocategorias, indices_subtipos, 'Subtipo')

# exibe tabelas
display(consolidado_metodos)
display(consolidado_categorias)
display(consolidado_subcategorias)
display(consolidado_subtipos)
# Out:
#                                 Método/Macrocategoria  \
# 0       A. Critérios Ergonômicos de Usabilidade (CEU)
# 26    B. Dimensões Principais da User Experience (UX)
# 55  C. Princípios Básicos da Interação Humano-Dado...
# 59                                              Total
#
#     Frequência absoluta (ni)  Frequência relativa (fi)  Positivos (ni)  \
# 0                        150                     0.357              31
# 26                       185                     0.440              64
# 55                        85                     0.202              24
# 59                       420                     1.000             119
#
#     Positivos (fi)  Negativos (ni)  Negativos (fi)
# 0            0.261             119           0.395
# 26           0.538             121           0.402
# 55           0.202              61           0.203
# 59           1.000             301           1.000
#                                       Categoria  Frequência absoluta (ni)  \
# ...

# %%
# pré-tratamento do dataframe
consolidado_metodos.reset_index(inplace = True, drop = False)
consolidado_metodos['Método/Macrocategoria'] = {0: 'Critérios Ergonômicos de Usabilidade', 1: 'Dimensões principais da UX', 
                                                2: 'Princípios Básicos da IHD', 3: 'Total'}
display(consolidado_metodos)

# %%
# gera gráfico de questões levantadas por método/macrocategoria e viés
titulo = "Pontos observados por macrocategoria e viés"
linha_fina = "Número de questões elicitadas por meio dos registros (excertos) analisados"
fonte = "Fonte: a autora"
nome_arquivo = 'questoes_macrocategoria_geral.png'
limite_cor = 8
intervalo = [i * 25 for i in range(10)] # define exibição de múltiplos de 10 no eixo x
limite_max_x = 206
gera_grafico_vies(consolidado_metodos, 'Método/Macrocategoria', titulo, linha_fina, fonte, nome_arquivo, limite_cor, limite_max_x,
                  intervalo, cor_positivo, cor_negativo)

# %%
# pré-tratamento do dataframe
consolidado_categorias.reset_index(inplace = True, drop = False)
consolidado_categorias['Categoria'] = {0: 'Condução', 1: 'Carga de Trabalho', 2: 'Controle Explícito', 3: 'Adaptabilidade', 
                                       4: 'Gestão de Erros', 5: 'Coerência/Consistência (Homogeneidade)', 
                                       6: 'Significado dos Códigos e Denominações', 7: 'Compatibilidade', 
                                       8: 'Qualidade Pragmática', 9: 'Qualidade Hedônica', 10: 'Construtos Avaliativos',
                                       11: 'Agência', 12: 'Legibilidade', 13: 'Negociabilidade', 14: 'Total'}
consolidado_categorias['Macro'] = {0: 'CEU', 1: 'CEU', 2: 'CEU', 3: 'CEU', 4: 'CEU', 5: 'CEU', 6: 'CEU', 7: 'CEU', 
                                       8: 'UX', 9: 'UX', 10: 'UX',
                                       11: 'IHD', 12: 'IHD', 13: 'IHD', 14: 'Total'}

display(consolidado_categorias)

# %%
# gera gráfico de questões levantadas por categoria e macrocategoria
# define cores personalizadas para o gráfico
cor_ceu = "#C295AD"
cor_ux = "#95ACC2"
cor_ihd = "#9AC295"
# define parâmetros de informação
titulo = "Pontos observados por categoria"
linha_fina = "Número de questões elicitadas por meio dos registros (excertos) analisados"
fonte = "Fonte: a autora"
nome_arquivo = 'questoes_categoria_geral.png'
limite_cor = 25
# define intervalo de grande e o limite máximo do eixo x
intervalo = [i * 10 for i in range(14)] # define exibição de múltiplos de 10 no eixo x
limite_max_x = 133


gera_grafico_categorias(consolidado_categorias, 'Frequência absoluta (ni)','Categoria', 0.6, titulo, linha_fina, fonte, nome_arquivo, 
                        limite_cor, limite_max_x, intervalo, cor_ceu, cor_ux, cor_ihd)

# %%
# cria árvore de categorias para facilitar visualização dos dados
arvore_geral = cria_arvore(consolidado_macrocategorias, 'Frequência absoluta (ni)')
#display(arvore_geral)

# %% [markdown]
# ### **Categorias - Brasil.io (iniciativa voluntária)**

# %% [markdown]
# #### **Tabulação geral por registros analisados**

# %%
# registros analisados por usuário e por viés
total_brasil_io = len(brasil_io.index)
consolidado_usuarios_brasil_io = cria_tabela_consolidada(brasil_io, total_brasil_io, brasil_io_positivos, brasil_io_negativos, 'Usuário', 3)
display(consolidado_usuarios_brasil_io)

# %%
# registros analisados por fonte e por viés (OBS.: fazer mais uma função que conte apenas uma, duas, três  etc fontes e quais)
linhas_recorte_brasil_io = range(0,31)
frequencia_fontes_registros_brasil_io = tabula_colunas(brasil_io, linhas_recorte_brasil_io, colunas_fontes, total_brasil_io)
display(frequencia_fontes_registros_brasil_io)

# %%
# registros analisados por categoria
frequencia_categorias_brasil_io = tabula_colunas(brasil_io, linhas_recorte_brasil_io, colunas_categorias, total_brasil_io)
display(frequencia_categorias_brasil_io)

# %%
# registros analisados por viés, em dataframes intermediários, para construção da tabulação por questões encontradas
recorte_positivos_brasil_io = range(0,6)
recorte_negativos_brasil_io = range(0,25)
frequencia_categorias_positivos_brasil_io = tabula_colunas(brasil_io_positivos, recorte_positivos_brasil_io, 
                                                           colunas_categorias, total_brasil_io)
frequencia_categorias_negativos_brasil_io = tabula_colunas(brasil_io_negativos, recorte_negativos_brasil_io, 
                                                           colunas_categorias, total_brasil_io)
# tabulação das questões encontradas nos registros e categorizadas
# atenção: um registro pode ter sido categorizado em mais de uma questão e há quatro níveis hierárquicos de categorias
consolidado_macrocategorias_brasil_io = tabula_questoes(frequencia_categorias_brasil_io, frequencia_categorias_positivos_brasil_io, 
                                                        frequencia_categorias_negativos_brasil_io, 'F.A.', 'F.R.', 'Categoria', 59)
display(consolidado_macrocategorias_brasil_io)

# %%
# gera tabela resumida apenas com as macrocategorias/ métodos usados na análise
consolidado_metodos_brasil_io = extratifica_tabela(consolidado_macrocategorias_brasil_io, indices_macrocategorias, 
                                                   'Método/ Macrocategoria')
# gera tabela resumida apenas com as categorias (segundo nível de classificação)
consolidado_categorias_brasil_io = extratifica_tabela(consolidado_macrocategorias_brasil_io, indices_categorias, 'Categoria')
# gera tabela resumida apenas com as subcategorias (terceiro nível de classificação)
consolidado_subcategorias_brasil_io = extratifica_tabela(consolidado_macrocategorias_brasil_io, indices_subcategorias, 'Subcategoria')
# gera tabela resumida apenas com os subtipos (quarto nível de classificação)
consolidado_subtipos_brasil_io = extratifica_tabela(consolidado_macrocategorias_brasil_io, indices_subtipos, 'Subtipo')

# exibe tabelas
display(consolidado_metodos_brasil_io)
display(consolidado_categorias_brasil_io)
display(consolidado_subcategorias_brasil_io)
display(consolidado_subtipos_brasil_io)

# %% [markdown]
# ### **Categorias - Coronavírus Brasil (Ministério da Saúde)**

# %%
# registros analisados por usuário e por viés
total_coronavirus_brasil = len(coronavirus_brasil.index)
consolidado_usuarios_coronavirus_brasil = cria_tabela_consolidada(coronavirus_brasil, total_coronavirus_brasil, 
                                                                  coronavirus_brasil_positivos, coronavirus_brasil_negativos, 
                                                                  'Usuário', 3)
display(consolidado_usuarios_coronavirus_brasil)

# %%
# registros analisados por fonte e por viés (OBS.: fazer mais uma função que conte apenas uma, duas, três  etc fontes e quais)
linhas_recorte_coronavirus_brasil = range(0,33)
frequencia_fontes_registros_coronavirus_brasil = tabula_colunas(coronavirus_brasil, linhas_recorte_coronavirus_brasil, 
                                                                colunas_fontes, total_coronavirus_brasil)
display(frequencia_fontes_registros_coronavirus_brasil)

# %%
# registros analisados por categoria
frequencia_categorias_coronavirus_brasil = tabula_colunas(coronavirus_brasil, linhas_recorte_coronavirus_brasil, 
                                                          colunas_categorias, total_coronavirus_brasil)
display(frequencia_categorias_coronavirus_brasil)

# %%
# registros analisados por viés, em dataframes intermediários, para construção da tabulação por questões encontradas
recorte_positivos_coronavirus_brasil = range(0,2)
recorte_negativos_coronavirus_brasil = range(0,31)
frequencia_categorias_positivos_coronavirus_brasil = tabula_colunas(coronavirus_brasil_positivos, 
                                                                    recorte_positivos_coronavirus_brasil, 
                                                                    colunas_categorias, total_coronavirus_brasil)
frequencia_categorias_negativos_coronavirus_brasil = tabula_colunas(coronavirus_brasil_negativos, 
                                                                    recorte_negativos_coronavirus_brasil, 
                                                                    colunas_categorias, total_coronavirus_brasil)
# tabulação das questões encontradas nos registros e categorizadas
# atenção: um registro pode ter sido categorizado em mais de uma questão e há quatro níveis hierárquicos de categorias
consolidado_macrocategorias_coronavirus_brasil = tabula_questoes(frequencia_categorias_coronavirus_brasil, 
                                                                 frequencia_categorias_positivos_coronavirus_brasil, 
                                                                 frequencia_categorias_negativos_coronavirus_brasil, 
                                                                 'F.A.', 'F.R.', 'Categoria', 59)
display(consolidado_macrocategorias_coronavirus_brasil)

# %%
# gera tabela resumida apenas com as macrocategorias/ métodos usados na análise
consolidado_metodos_coronavirus_brasil = extratifica_tabela(consolidado_macrocategorias_coronavirus_brasil, indices_macrocategorias, 
                                                            'Método/ Macrocategoria')
# gera tabela resumida apenas com as categorias (segundo nível de classificação)
consolidado_categorias_coronavirus_brasil = extratifica_tabela(consolidado_macrocategorias_coronavirus_brasil, indices_categorias, 
                                                               'Categoria')
# gera tabela resumida apenas com as subcategorias (terceiro nível de classificação)
consolidado_subcategorias_coronavirus_brasil = extratifica_tabela(consolidado_macrocategorias_coronavirus_brasil, indices_subcategorias, 
                                                                  'Subcategoria')
# gera tabela resumida apenas com os subtipos (quarto nível de classificação)
consolidado_subtipos_coronavirus_brasil = extratifica_tabela(consolidado_macrocategorias_coronavirus_brasil, indices_subtipos, 
                                                             'Subtipo')

# exibe tabelas
display(consolidado_metodos_coronavirus_brasil)
display(consolidado_categorias_coronavirus_brasil)
display(consolidado_subcategorias_coronavirus_brasil)
display(consolidado_subtipos_coronavirus_brasil)

# %% [markdown]
# ### **Categorias - MonitoraCovid-19 (Fiocruz)**

# %%
# registros analisados por usuário e por viés
total_monitora_covid = len(monitora_covid.index)
consolidado_usuarios_monitora_covid = cria_tabela_consolidada(monitora_covid, total_monitora_covid, monitora_covid_positivos, 
                                                              monitora_covid_negativos, 'Usuário', 3)
display(consolidado_usuarios_monitora_covid)

# %%
# registros analisados por fonte e por viés (OBS.: fazer mais uma função que conte apenas uma, duas, três  etc fontes e quais)
linhas_recorte_monitora_covid = range(0,34)
frequencia_fontes_registros_monitora_covid = tabula_colunas(monitora_covid, linhas_recorte_monitora_covid, colunas_fontes, 
                                                            total_monitora_covid)
display(frequencia_fontes_registros_monitora_covid)

# %%
# registros analisados por categoria
frequencia_categorias_monitora_covid = tabula_colunas(monitora_covid, linhas_recorte_monitora_covid, colunas_categorias, 
                                                      total_monitora_covid)
display(frequencia_categorias_monitora_covid)

# %%
# registros analisados por viés, em dataframes intermediários, para construção da tabulação por questões encontradas
recorte_positivos_monitora_covid = range(0,15)
recorte_negativos_monitora_covid = range(0,19)
frequencia_categorias_positivos_monitora_covid = tabula_colunas(monitora_covid_positivos, recorte_positivos_monitora_covid, 
                                                                colunas_categorias, total_monitora_covid)
frequencia_categorias_negativos_monitora_covid = tabula_colunas(monitora_covid_negativos, recorte_negativos_monitora_covid, 
                                                                colunas_categorias, total_monitora_covid)
# tabulação das questões encontradas nos registros e categorizadas
# atenção: um registro pode ter sido categorizado em mais de uma questão e há quatro níveis hierárquicos de categorias
consolidado_macrocategorias_monitora_covid = tabula_questoes(frequencia_categorias_monitora_covid, 
                                                             frequencia_categorias_positivos_monitora_covid, 
                                                             frequencia_categorias_negativos_monitora_covid, 
                                                             'F.A.', 'F.R.', 'Categoria', 59)
display(consolidado_macrocategorias_monitora_covid)

# %%
# gera tabela resumida apenas com as macrocategorias/ métodos usados na análise
consolidado_metodos_monitora_covid = extratifica_tabela(consolidado_macrocategorias_monitora_covid, indices_macrocategorias, 
                                                        'Método/ Macrocategoria')
# gera tabela resumida apenas com as categorias (segundo nível de classificação)
consolidado_categorias_monitora_covid = extratifica_tabela(consolidado_macrocategorias_monitora_covid, indices_categorias, 'Categoria')
# gera tabela resumida apenas com as subcategorias (terceiro nível de classificação)
consolidado_subcategorias_monitora_covid = extratifica_tabela(consolidado_macrocategorias_monitora_covid, indices_subcategorias, 
                                                              'Subcategoria')
# gera tabela resumida apenas com os subtipos (quarto nível de classificação)
consolidado_subtipos_monitora_covid = extratifica_tabela(consolidado_macrocategorias_monitora_covid, indices_subtipos, 'Subtipo')

# exibe tabelas
display(consolidado_metodos_monitora_covid)
display(consolidado_categorias_monitora_covid)
display(consolidado_subcategorias_monitora_covid)
display(consolidado_subtipos_monitora_covid)

# %% [markdown]
# ### **Categorias - Painel Nacional: Covid-19 (CONASS)**

# %%
# registros analisados por usuário e por viés
total_painel_nacional = len(painel_nacional.index)
consolidado_usuarios_painel_nacional = cria_tabela_consolidada(painel_nacional, total_painel_nacional, painel_nacional_positivos, 
                                                               painel_nacional_negativos, 'Usuário', 3)
display(consolidado_usuarios_painel_nacional)

# %%
# registros analisados por fonte e por viés (OBS.: fazer mais uma função que conte apenas uma, duas, três  etc fontes e quais)
linhas_recorte_painel_nacional = range(0,19)
frequencia_fontes_registros_painel_nacional = tabula_colunas(painel_nacional, linhas_recorte_painel_nacional, colunas_fontes, 
                                                             total_painel_nacional)
display(frequencia_fontes_registros_painel_nacional)

# %%
# registros analisados por categoria
frequencia_categorias_painel_nacional = tabula_colunas(painel_nacional, linhas_recorte_painel_nacional, colunas_categorias, 
                                                       total_painel_nacional)
display(frequencia_categorias_painel_nacional)

# %%
# registros analisados por viés, em dataframes intermediários, para construção da tabulação por questões encontradas
recorte_positivos_painel_nacional = range(0,8)
recorte_negativos_painel_nacional = range(0,11)
frequencia_categorias_positivos_painel_nacional = tabula_colunas(painel_nacional_positivos, recorte_positivos_painel_nacional, 
                                                                 colunas_categorias, total_painel_nacional)
frequencia_categorias_negativos_painel_nacional = tabula_colunas(painel_nacional_negativos, recorte_negativos_painel_nacional, 
                                                                 colunas_categorias, total_painel_nacional)
# tabulação das questões encontradas nos registros e categorizadas
# atenção: um registro pode ter sido categorizado em mais de uma questão e há quatro níveis hierárquicos de categorias
consolidado_macrocategorias_painel_nacional = tabula_questoes(frequencia_categorias_painel_nacional, 
                                                              frequencia_categorias_positivos_painel_nacional, 
                                                              frequencia_categorias_negativos_painel_nacional, 
                                                              'F.A.', 'F.R.', 'Categoria', 59)
display(consolidado_macrocategorias_painel_nacional)

# %%
# gera tabela resumida apenas com as macrocategorias/ métodos usados na análise
consolidado_metodos_painel_nacional = extratifica_tabela(consolidado_macrocategorias_painel_nacional, indices_macrocategorias, 
                                                         'Método/ Macrocategoria')
# gera tabela resumida apenas com as categorias (segundo nível de classificação)
consolidado_categorias_painel_nacional = extratifica_tabela(consolidado_macrocategorias_painel_nacional, indices_categorias, 
                                                            'Categoria')
# gera tabela resumida apenas com as subcategorias (terceiro nível de classificação)
consolidado_subcategorias_painel_nacional = extratifica_tabela(consolidado_macrocategorias_painel_nacional, indices_subcategorias, 
                                                               'Subcategoria')
# gera tabela resumida apenas com os subtipos (quarto nível de classificação)
consolidado_subtipos_painel_nacional = extratifica_tabela(consolidado_macrocategorias_painel_nacional, indices_subtipos, 'Subtipo')

# exibe tabelas
display(consolidado_metodos_painel_nacional)
display(consolidado_categorias_painel_nacional)
display(consolidado_subcategorias_painel_nacional)
display(consolidado_subtipos_painel_nacional)

# %% [markdown]
# ## **Nuvens de palavras**

# %% [markdown]
# **Passos iniciais**

# %%
# delimita as palavras dos comentários que devem ser eliminadas da nuvem de palavras
lista_stopwords = ['o','a','os','as','um','uma','uns','umas','de','da','do','das','dos','em','no','na','nos','nas','à','ao',
                   'para','pra','prá','pro','pras','prás','pros','neste','nesta','nestes','nestas','deste','desta','destes',
                   'destas','nesses','nessas','desse','dessa','desses','dessas','nisso','nisto','naquilo','disso','disto',
                   'daquilo','naquele','naquela','naqueles','naquelas','daquele','daquela','daqueles','daquelas','àquele',
                   'àquela','àqueles','àquelas','àquilo','ante','após','até','contra','desde','entre','perante','por','per',
                   'sob','sobre','trás','pelo','pela','pelos','pelas','outro','outra','outros','outras','eu','você','ele',
                   'ela','eles','elas','seu','sua','seus','suas','teu','tua','teus','tuas','dele','dela','deles','delas',
                   'nele','nela','neles','nelas','meu','me','comigo','consigo','contigo','isto','isso','aquilo','este','esta',
                   'estes','estas','esse','essa','esses','essas','aquele','aquela','aqueles','aquelas','todo','toda','todos',
                   'todas','cada','que','muitos','poucos','ser','sendo','é','foi','era','sou','somos','são','era','éramos',
                   'eram','fui','foi','fomos','foram','fora','fôramos','seja','sejamos','sejam','fosse','fôssemos','fossem',
                   'for','formos','forem','serei','será','seremos','serão','seria','seríamos','seriam','estar','está','estão',
                   'tá','tão','estando','estou','estamos','estive','esteve','estivemos','estiveram','estava','estávamos','estavam',
                   'estivera','estivéramos','esteja','estejamos','estejam','estivesse','estivéssemos','estivessem','estiver',
                   'estivermos','estiverem','ir','ía','ia','iria','fui','indo','vir','vai','vou','vindo','ficar','ficou','ficam',
                   'ficando','fiquei','fazer','faz', 'fez','feita', 'feito','e','ou','mas','também','se','nem','ai','aí','aqui',
                   'lá','ali','já','não','mais','menos','muito','pouco','assim','bem','mal','bastante','só','somente',
                   'onde','como', 'quando','quem','tudo','nada','com','sem', 'ID1','obs','.','duas','mil','painel','dados',
                   'primeiro', 'primeiros', 'primeira', 'primeiras', 'depois', 'qual', 'quais', 'qualquer', 'quaisquer'
                   #'dado','painéis','página','informação','informações','site','município','municípios','estado','estados','PR','letalidade',
                   ]
# fazer uma visão com 'dados' e 'painel' e as demais sem

# abre uma imagem e a transforma em um array do numpy
mascara_covid = np.array(Image.open('/home/marisa/Documentos/acadêmico/UFPR/TCC/usabilidade_ux_paineis_covid/imagens/covid_4.png'))

# %% [markdown]
# **Nuvens completas**
#
# - Geral - todos os comentários de todos os painéis:

# %%
# define quais serão os textos analisados para formar a nuvem de palavras
comentarios = ' '.join(paineis_covid["Comentário"].tolist())
# define o gradiente de cores da nuvem de palavras
cores = ["#BF0A30", "#002868"]
# gera e exibe a visualização da nuvem de palavras
cria_nuvem(comentarios,lista_stopwords,mascara_covid,cores,'nuvem_completa_geral.png')

# %% [markdown]
# - Brasil.io (iniciativa voluntária) - todos os comentários referentes ao painel:

# %%
comentarios_brasil_io = ' '.join(brasil_io["Comentário"].tolist())
cores_brasil_io = ["#019112", "#733506"]
cria_nuvem(comentarios_brasil_io,lista_stopwords,mascara_covid,cores_brasil_io,'nuvem_completa_brasil_io.png')

# %% [markdown]
# - Coronavírus Brasil (Ministério da Saúde) - todos os comentários referentes ao painel:

# %%
comentarios_coronavirus_brasil = ' '.join(coronavirus_brasil["Comentário"].tolist())
cores_coronavirus_brasil = ["#A3035B", "#006E65"]
cria_nuvem(comentarios_coronavirus_brasil,lista_stopwords,mascara_covid,cores_coronavirus_brasil,'nuvem_completa_coronavirus_brasil.png')

# %% [markdown]
# - MonitoraCovid-19 (Fiocruz) - todos os comentários referentes ao painel:

# %%
comentarios_monitora_covid = ' '.join(monitora_covid["Comentário"].tolist())
cores_monitora_covid = ["#4D4B4C", "#F50062"]
cria_nuvem(comentarios_monitora_covid,lista_stopwords,mascara_covid,cores_monitora_covid,'nuvem_completa_monitora_covid.png')

# %% [markdown]
# - Painel Nacional: Covid-19 (CONASS) - todos os comentários referentes ao painel:

# %%
comentarios_painel_nacional = ' '.join(painel_nacional["Comentário"].tolist())
cores_painel_nacional = ["#FF4500", "#23305C"]
cria_nuvem(comentarios_painel_nacional,lista_stopwords,mascara_covid,cores_painel_nacional,'nuvem_completa_painel_nacional.png')

# %% [markdown]
# **Nuvens registros positivos**
#
# - Geral - comentários positivos de todos os painéis:

# %%
comentarios_positivos = ' '.join(positivos["Comentário"].tolist())
cria_nuvem(comentarios_positivos,lista_stopwords,mascara_covid,cores, 'nuvem_positivos_geral.png')

# %% [markdown]
# - Brasil.io (iniciativa voluntária) - comentários positivos referentes ao painel:

# %%
comentarios_positivos_brasil_io = ' '.join(brasil_io_positivos["Comentário"].tolist())
cria_nuvem(comentarios_positivos_brasil_io,lista_stopwords,mascara_covid,cores_brasil_io,'nuvem_positivos_brasil_io.png')

# %% [markdown]
# - Coronavírus Brasil (Ministério da Saúde) - comentários positivos referentes ao painel:

# %%
comentarios_positivos_coronavirus_brasil = ' '.join(coronavirus_brasil_positivos["Comentário"].tolist())
cria_nuvem(comentarios_positivos_coronavirus_brasil,lista_stopwords,mascara_covid,cores_coronavirus_brasil,'nuvem_positivos_coronavirus_brasil.png')

# %% [markdown]
# - MonitoraCovid-19 (Fiocruz) - comentários positivos referentes ao painel:

# %%
comentarios_positivos_monitora_covid = ' '.join(monitora_covid_positivos["Comentário"].tolist())
cria_nuvem(comentarios_positivos_monitora_covid,lista_stopwords,mascara_covid,cores_monitora_covid, 'nuvem_positivos_monitora_covid.png')

# %% [markdown]
# - Painel Nacional: Covid-19 (CONASS) - comentários positivos referentes ao painel:

# %%
comentarios_positivos_painel_nacional = ' '.join(painel_nacional_positivos["Comentário"].tolist())
cria_nuvem(comentarios_positivos_painel_nacional,lista_stopwords,mascara_covid,cores_painel_nacional,'nuvem_positivos_painel_nacional.png')

# %% [markdown]
# **Nuvens registros negativos**
#
# - Geral - comentários negativos de todos os painéis:

# %%
comentarios_negativos = ' '.join(negativos["Comentário"].tolist())
cria_nuvem(comentarios_negativos,lista_stopwords,mascara_covid,cores,'nuvem_negativos_geral.png')

# %% [markdown]
# - Brasil.io (iniciativa voluntária) - comentários negativos referentes ao painel:

# %%
comentarios_negativos_brasil_io = ' '.join(brasil_io_negativos["Comentário"].tolist())
cria_nuvem(comentarios_negativos_brasil_io,lista_stopwords,mascara_covid,cores_brasil_io,'nuvem_negativos_brasil_io.png')

# %% [markdown]
# - Coronavírus Brasil (Ministério da Saúde) - comentários negativos referentes ao painel:

# %%
comentarios_negativos_coronavirus_brasil = ' '.join(coronavirus_brasil_negativos["Comentário"].tolist())
cria_nuvem(comentarios_negativos_coronavirus_brasil,lista_stopwords,mascara_covid,cores_coronavirus_brasil,'nuvem_negativos_coronavirus_brasil.png')

# %% [markdown]
# - MonitoraCovid-19 (Fiocruz) - comentários negativos referentes ao painel:

# %%
comentarios_negativos_monitora_covid = ' '.join(monitora_covid_negativos["Comentário"].tolist())
cria_nuvem(comentarios_negativos_monitora_covid,lista_stopwords,mascara_covid,cores_monitora_covid,'nuvem_negativos_monitora_covid.png')

# %% [markdown]
# - Painel Nacional: Covid-19 (CONASS) - comentários negativos referentes ao painel:

# %%
comentarios_negativos_painel_nacional = ' '.join(painel_nacional_negativos["Comentário"].tolist())
cria_nuvem(comentarios_negativos_painel_nacional,lista_stopwords,mascara_covid,cores_painel_nacional,'nuvem_negativos_painel_nacional.png')

# %% [markdown]
# ## **Tabulações por usuário**

# %% [markdown]
# ### **Tabulação usuário 1 - Ergonomia/Design**

# %%
# cria subconjuntos de registros do usuário, positivos e negativos
usuario_1 = paineis_covid.query("Usuário == 1")
positivos_usuario_1 = positivos.query("Usuário == 1")
negativos_usuario_1 = negativos.query("Usuário == 1")

# cria subconjuntos de registros relacionados ao painel Brasil.io (iniciativa voluntária)
brasil_io_usuario_1 = usuario_1.query("Painel == 'Brasil.io (iniciativa voluntária)'")
brasil_io_positivos_usuario_1 = positivos_usuario_1.query("Painel == 'Brasil.io (iniciativa voluntária)'")
brasil_io_negativos_usuario_1 = negativos_usuario_1.query("Painel == 'Brasil.io (iniciativa voluntária)'")

# cria subconjuntos de registros relacionados ao painel Coronavírus Brasil (Ministério da Saúde)
coronavirus_brasil_usuario_1 = usuario_1.query("Painel == 'Coronavírus Brasil (Ministério da Saúde)'")
coronavirus_brasil_positivos_usuario_1 = positivos_usuario_1.query("Painel == 'Coronavírus Brasil (Ministério da Saúde)'")
coronavirus_brasil_negativos_usuario_1 = negativos_usuario_1.query("Painel == 'Coronavírus Brasil (Ministério da Saúde)'")

# cria subconjuntos de registros relacionados ao painel MonitoraCovid-19 (Fiocruz)
monitora_covid_usuario_1 = usuario_1.query("Painel == 'MonitoraCovid-19 (Fiocruz)'")
monitora_covid_positivos_usuario_1 = positivos_usuario_1.query("Painel == 'MonitoraCovid-19 (Fiocruz)'")
monitora_covid_negativos_usuario_1 = negativos_usuario_1.query("Painel == 'MonitoraCovid-19 (Fiocruz)'")

# cria subconjuntos de registros relacionados ao painel Painel Nacional: Covid-19 (CONASS)
painel_nacional_usuario_1 = usuario_1.query("Painel == 'Painel Nacional: Covid-19 (CONASS)'")
painel_nacional_positivos_usuario_1 = positivos_usuario_1.query("Painel == 'Painel Nacional: Covid-19 (CONASS)'")
painel_nacional_negativos_usuario_1 = negativos_usuario_1.query("Painel == 'Painel Nacional: Covid-19 (CONASS)'")

# %%
total_usuario_1 = len(usuario_1.index)
# registros analisados por painel e por viés
consolidado_paineis_usuario_1 = cria_tabela_consolidada(usuario_1, total_usuario_1, positivos_usuario_1, negativos_usuario_1, 'Painel', 4)
display(consolidado_paineis_usuario_1)

# %%
# define cores personalizadas para o gráfico
consolidado_paineis_usuario_1['Painel'] = {0: 'MonitoraCovid-19', 1: 'Coronavírus Brasil', 2: 'Brasil.io', 3: 'Painel Nacional: Covid-19',
                                4: 'Total'}
#cor_positivo = "#FFA500"
#cor_negativo = "#61088A"
# define parâmetros de informação
titulo = "Registros do usuário ID1 por painel e viés"
linha_fina = "Número de registros (excertos) analisados"
fonte = "Fonte: a autora"
nome_arquivo = 'painel_vies_id1.png'
limite_cor = 5
intervalo = [i * 5 for i in range(5)] # define exibição de múltiplos de 10 no eixo x
limite_max_x = 16
gera_grafico_vies(consolidado_paineis_usuario_1, 'Painel', titulo, linha_fina, fonte, nome_arquivo, limite_cor, limite_max_x,
                  intervalo, cor_positivo, cor_negativo)

# %%
# registros analisados por fonte e por viés (OBS.: fazer mais uma função que conte apenas uma, duas, três  etc fontes e quais)
linhas_recorte_usuario_1 = range(0,33)
frequencia_fontes_registros_total_usuario_1 = tabula_colunas(usuario_1, linhas_recorte_usuario_1, colunas_fontes, total_usuario_1)
display(frequencia_fontes_registros_total_usuario_1)

# %% [markdown]
# #### **Tabulação geral das categorias por registros analisados**

# %%
# registros analisados por categoria
frequencia_categorias_usuario_1 = tabula_colunas(usuario_1, linhas_recorte_usuario_1, colunas_categorias, total_usuario_1)
display(frequencia_categorias_usuario_1) # creio que não usarei esta parte na análise - APAGAR

# %% [markdown]
# #### **Tabulação geral das categorias por questões encontradas nos registros e categorizadas**

# %%
# registros analisados por viés, em dataframes intermediários, para construção da tabulação por questões encontradas
recorte_positivos_usuario_1 = range(0,7)
recorte_negativos_usuario_1 = range(0,26)
frequencia_categorias_positivos_usuario_1 = tabula_colunas(positivos_usuario_1, recorte_positivos_usuario_1, colunas_categorias, 
                                                           total_usuario_1)
frequencia_categorias_negativos_usuario_1 = tabula_colunas(negativos_usuario_1, recorte_negativos_usuario_1, colunas_categorias, 
                                                           total_usuario_1)
# tabulação das questões encontradas nos registros e categorizadas
# atenção: um registro pode ter sido categorizado em mais de uma questão e há quatro níveis hierárquicos de categorias
consolidado_macrocategorias_usuario_1 = tabula_questoes(frequencia_categorias_usuario_1, frequencia_categorias_positivos_usuario_1, 
                                                        frequencia_categorias_negativos_usuario_1, 'F.A.', 'F.R.', 'Categoria', 59)
display(consolidado_macrocategorias_usuario_1)

# %%
# gera tabela resumida apenas com as macrocategorias/ métodos usados na análise
consolidado_metodos_usuario_1 = extratifica_tabela(consolidado_macrocategorias_usuario_1, indices_macrocategorias, 
                                                   'Método/ Macrocategoria')
# gera tabela resumida apenas com as categorias (segundo nível de classificação)
consolidado_categorias_usuario_1 = extratifica_tabela(consolidado_macrocategorias_usuario_1, indices_categorias, 
                                                      'Categoria')
# gera tabela resumida apenas com as subcategorias (terceiro nível de classificação)
consolidado_subcategorias_usuario_1 = extratifica_tabela(consolidado_macrocategorias_usuario_1, indices_subcategorias, 
                                                         'Subcategoria')
# gera tabela resumida apenas com os subtipos (quarto nível de classificação)
consolidado_subtipos_usuario_1 = extratifica_tabela(consolidado_macrocategorias_usuario_1, indices_subtipos, 'Subtipo')

# exibe tabelas
display(consolidado_metodos_usuario_1)
display(consolidado_categorias_usuario_1)
display(consolidado_subcategorias_usuario_1)
display(consolidado_subtipos_usuario_1)

# %% [markdown]
# #### **Nuvens de palavras**

# %%
# gera nuvem completa do usuário 1
comentarios_usuario_1 = ' '.join(usuario_1["Comentário"].tolist())
cores_1 = ["#FFA500", "#61088A"]
cria_nuvem(comentarios_usuario_1,lista_stopwords,mascara_covid,cores_1,'nuvem_geral_id1.png')

# %%
# gera nuvem de registros com viés positivo do usuário 1
comentarios_positivos_usuario_1 = ' '.join(positivos_usuario_1["Comentário"].tolist())
cria_nuvem(comentarios_positivos_usuario_1,lista_stopwords,mascara_covid,cores_1,'nuvem_positivos_id1.png')

# %%
# gera nuvem de registros com viés negativo do usuário 1
comentarios_negativos_usuario_1 = ' '.join(negativos_usuario_1["Comentário"].tolist())
cria_nuvem(comentarios_negativos_usuario_1,lista_stopwords,mascara_covid,cores_1,'nuvem_negativos_id1.png')

# %% [markdown]
# ### **Tabulação usuário 2 - Dados**

# %%
# cria subconjuntos de registros do usuário, positivos e negativos
usuario_2 = paineis_covid.query("Usuário == 2")
positivos_usuario_2 = positivos.query("Usuário == 2")
negativos_usuario_2 = negativos.query("Usuário == 2")

# cria subconjuntos de registros relacionados ao painel Brasil.io (iniciativa voluntária)
brasil_io_usuario_2 = usuario_2.query("Painel == 'Brasil.io (iniciativa voluntária)'")
brasil_io_positivos_usuario_2 = positivos_usuario_2.query("Painel == 'Brasil.io (iniciativa voluntária)'")
brasil_io_negativos_usuario_2 = negativos_usuario_2.query("Painel == 'Brasil.io (iniciativa voluntária)'")

# cria subconjuntos de registros relacionados ao painel Coronavírus Brasil (Ministério da Saúde)
coronavirus_brasil_usuario_2 = usuario_2.query("Painel == 'Coronavírus Brasil (Ministério da Saúde)'")
coronavirus_brasil_positivos_usuario_2 = positivos_usuario_2.query("Painel == 'Coronavírus Brasil (Ministério da Saúde)'")
coronavirus_brasil_negativos_usuario_2 = negativos_usuario_2.query("Painel == 'Coronavírus Brasil (Ministério da Saúde)'")

# cria subconjuntos de registros relacionados ao painel MonitoraCovid-19 (Fiocruz)
monitora_covid_usuario_2 = usuario_2.query("Painel == 'MonitoraCovid-19 (Fiocruz)'")
monitora_covid_positivos_usuario_2 = positivos_usuario_2.query("Painel == 'MonitoraCovid-19 (Fiocruz)'")
monitora_covid_negativos_usuario_2 = negativos_usuario_2.query("Painel == 'MonitoraCovid-19 (Fiocruz)'")

# cria subconjuntos de registros relacionados ao painel Painel Nacional: Covid-19 (CONASS)
painel_nacional_usuario_2 = usuario_2.query("Painel == 'Painel Nacional: Covid-19 (CONASS)'")
painel_nacional_positivos_usuario_2 = positivos_usuario_2.query("Painel == 'Painel Nacional: Covid-19 (CONASS)'")
painel_nacional_negativos_usuario_2 = negativos_usuario_2.query("Painel == 'Painel Nacional: Covid-19 (CONASS)'")

# %%
total_usuario_2 = len(usuario_2.index)
# registros analisados por painel e por viés
consolidado_paineis_usuario_2 = cria_tabela_consolidada(usuario_2, total_usuario_2, positivos_usuario_2, negativos_usuario_2, 'Painel', 4)
display(consolidado_paineis_usuario_2)

# %%
# define cores personalizadas para o gráfico
consolidado_paineis_usuario_2['Painel'] = {0: 'MonitoraCovid-19', 1: 'Coronavírus Brasil', 2: 'Brasil.io', 3: 'Painel Nacional: Covid-19',
                                4: 'Total'}
#cor_positivo = "#059E14"
#cor_negativo = "#9904B0"
# define parâmetros de informação
titulo = "Registros do usuário ID2 por painel e viés"
linha_fina = "Número de registros (excertos) analisados"
fonte = "Fonte: a autora"
nome_arquivo = 'painel_vies_id2.png'
limite_cor = 5
intervalo = [i * 5 for i in range(6)] # define exibição de múltiplos de 10 no eixo x
limite_max_x = 11
gera_grafico_vies(consolidado_paineis_usuario_2, 'Painel', titulo, linha_fina, fonte, nome_arquivo, limite_cor, limite_max_x,
                  intervalo, cor_positivo, cor_negativo)

# %%
# registros analisados por fonte e por viés (OBS.: fazer mais uma função que conte apenas uma, duas, três  etc fontes e quais)
linhas_recorte_usuario_2 = range(0,27)
frequencia_fontes_registros_total_usuario_2 = tabula_colunas(usuario_2, linhas_recorte_usuario_2, colunas_fontes, total_usuario_2)
display(frequencia_fontes_registros_total_usuario_2)

# %% [markdown]
# #### **Tabulação geral das categorias por registros analisados**

# %%
# registros analisados por categoria
frequencia_categorias_usuario_2 = tabula_colunas(usuario_2, linhas_recorte_usuario_2, colunas_categorias, total_usuario_2)
display(frequencia_categorias_usuario_2) # creio que não usarei esta parte na análise - APAGAR

# %% [markdown]
# #### **Tabulação geral das categorias por questões encontradas nos registros e categorizadas**

# %%
# registros analisados por viés, em dataframes intermediários, para construção da tabulação por questões encontradas
recorte_positivos_usuario_2 = range(0,7)
recorte_negativos_usuario_2 = range(0,20)
frequencia_categorias_positivos_usuario_2 = tabula_colunas(positivos_usuario_2, recorte_positivos_usuario_2, colunas_categorias, 
                                                           total_usuario_2)
frequencia_categorias_negativos_usuario_2 = tabula_colunas(negativos_usuario_2, recorte_negativos_usuario_2, colunas_categorias, 
                                                           total_usuario_2)
# tabulação das questões encontradas nos registros e categorizadas
# atenção: um registro pode ter sido categorizado em mais de uma questão e há quatro níveis hierárquicos de categorias
consolidado_macrocategorias_usuario_2 = tabula_questoes(frequencia_categorias_usuario_2, frequencia_categorias_positivos_usuario_2, 
                                                        frequencia_categorias_negativos_usuario_2, 'F.A.', 'F.R.', 'Categoria', 59)
display(consolidado_macrocategorias_usuario_2)

# %%
# gera tabela resumida apenas com as macrocategorias/ métodos usados na análise
consolidado_metodos_usuario_2 = extratifica_tabela(consolidado_macrocategorias_usuario_2, indices_macrocategorias, 
                                                   'Método/ Macrocategoria')
# gera tabela resumida apenas com as categorias (segundo nível de classificação)
consolidado_categorias_usuario_2 = extratifica_tabela(consolidado_macrocategorias_usuario_2, indices_categorias, 
                                                      'Categoria')
# gera tabela resumida apenas com as subcategorias (terceiro nível de classificação)
consolidado_subcategorias_usuario_2 = extratifica_tabela(consolidado_macrocategorias_usuario_2, indices_subcategorias, 
                                                         'Subcategoria')
# gera tabela resumida apenas com os subtipos (quarto nível de classificação)
consolidado_subtipos_usuario_2 = extratifica_tabela(consolidado_macrocategorias_usuario_2, indices_subtipos, 'Subtipo')

# exibe tabelas
display(consolidado_metodos_usuario_2)
display(consolidado_categorias_usuario_2)
display(consolidado_subcategorias_usuario_2)
display(consolidado_subtipos_usuario_2)

# %% [markdown]
# #### **Nuvens de palavras**

# %%
# gera nuvem completa do usuário 2
comentarios_usuario_2 = ' '.join(usuario_2["Comentário"].tolist())
cores_2 = ["#059E14", "#9904B0"]
cria_nuvem(comentarios_usuario_2,lista_stopwords,mascara_covid,cores_2,'nuvem_geral_id2.png')

# %%
# gera nuvem de registros com viés positivo do usuário 2
comentarios_positivos_usuario_2 = ' '.join(positivos_usuario_2["Comentário"].tolist())
cria_nuvem(comentarios_positivos_usuario_2,lista_stopwords,mascara_covid,cores_2,'nuvem_positivos_id2.png')

# %%
# gera nuvem de registros com viés negativo do usuário 2
comentarios_negativos_usuario_2 = ' '.join(negativos_usuario_2["Comentário"].tolist())
cria_nuvem(comentarios_negativos_usuario_2,lista_stopwords,mascara_covid,cores_2,'nuvem_negativos_id2.png')

# %% [markdown]
# ### **Tabulação usuário 3 - Saúde**

# %%
# cria subconjuntos de registros do usuário, positivos e negativos
usuario_3 = paineis_covid.query("Usuário == 3")
positivos_usuario_3 = positivos.query("Usuário == 3")
negativos_usuario_3 = negativos.query("Usuário == 3")

# cria subconjuntos de registros relacionados ao painel Brasil.io (iniciativa voluntária)
brasil_io_usuario_3 = usuario_3.query("Painel == 'Brasil.io (iniciativa voluntária)'")
brasil_io_positivos_usuario_3 = positivos_usuario_3.query("Painel == 'Brasil.io (iniciativa voluntária)'")
brasil_io_negativos_usuario_3 = negativos_usuario_3.query("Painel == 'Brasil.io (iniciativa voluntária)'")

# cria subconjuntos de registros relacionados ao painel Coronavírus Brasil (Ministério da Saúde)
coronavirus_brasil_usuario_3 = usuario_3.query("Painel == 'Coronavírus Brasil (Ministério da Saúde)'")
coronavirus_brasil_positivos_usuario_3 = positivos_usuario_3.query("Painel == 'Coronavírus Brasil (Ministério da Saúde)'")
coronavirus_brasil_negativos_usuario_3 = negativos_usuario_3.query("Painel == 'Coronavírus Brasil (Ministério da Saúde)'")

# cria subconjuntos de registros relacionados ao painel MonitoraCovid-19 (Fiocruz)
monitora_covid_usuario_3 = usuario_3.query("Painel == 'MonitoraCovid-19 (Fiocruz)'")
monitora_covid_positivos_usuario_3 = positivos_usuario_3.query("Painel == 'MonitoraCovid-19 (Fiocruz)'")
monitora_covid_negativos_usuario_3 = negativos_usuario_3.query("Painel == 'MonitoraCovid-19 (Fiocruz)'")

# cria subconjuntos de registros relacionados ao painel Painel Nacional: Covid-19 (CONASS)
painel_nacional_usuario_3 = usuario_3.query("Painel == 'Painel Nacional: Covid-19 (CONASS)'")
painel_nacional_positivos_usuario_3 = positivos_usuario_3.query("Painel == 'Painel Nacional: Covid-19 (CONASS)'")
painel_nacional_negativos_usuario_3 = negativos_usuario_3.query("Painel == 'Painel Nacional: Covid-19 (CONASS)'")

# %%
total_usuario_3 = len(usuario_3.index)
# registros analisados por painel e por viés
consolidado_paineis_usuario_3 = cria_tabela_consolidada(usuario_3, total_usuario_3, positivos_usuario_3, negativos_usuario_3, 'Painel', 4)
display(consolidado_paineis_usuario_3)

# %%
# define cores personalizadas para o gráfico
consolidado_paineis_usuario_3['Painel'] = {0: 'MonitoraCovid-19', 1: 'Coronavírus Brasil', 2: 'Brasil.io', 
                                          3: 'Painel Nacional: Covid-19', 4: 'Total'}
#cor_positivo = "#000AC4"
#cor_negativo = "#DB047E"
# define parâmetros de informação
titulo = "Registros do usuário ID3 por painel e viés"
linha_fina = "Número de registros (excertos) analisados"
fonte = "Fonte: a autora"
nome_arquivo = 'painel_vies_id3.png'
limite_cor = 8
intervalo = [i * 5 for i in range(6)] # define exibição de múltiplos de 10 no eixo x
limite_max_x = 21
gera_grafico_vies(consolidado_paineis_usuario_3, 'Painel', titulo, linha_fina, fonte, nome_arquivo, limite_cor, limite_max_x,
                  intervalo, cor_positivo, cor_negativo)

# %%
# registros analisados por fonte e por viés (OBS.: fazer mais uma função que conte apenas uma, duas, três  etc fontes e quais)
linhas_recorte_usuario_3 = range(0,57)
frequencia_fontes_registros_total_usuario_3 = tabula_colunas(usuario_3, linhas_recorte_usuario_3, colunas_fontes, total_usuario_3)
display(frequencia_fontes_registros_total_usuario_3)

# %% [markdown]
# #### **Tabulação geral das categorias por registros analisados**

# %%
# registros analisados por categoria
frequencia_categorias_usuario_3 = tabula_colunas(usuario_3, linhas_recorte_usuario_3, colunas_categorias, total_usuario_3)
display(frequencia_categorias_usuario_3) # creio que não usarei esta parte na análise - APAGAR

# %% [markdown]
# #### **Tabulação geral das categorias por questões encontradas nos registros e categorizadas**

# %%
# registros analisados por viés, em dataframes intermediários, para construção da tabulação por questões encontradas
recorte_positivos_usuario_3 = range(0,17)
recorte_negativos_usuario_3 = range(0,40)
frequencia_categorias_positivos_usuario_3 = tabula_colunas(positivos_usuario_3, recorte_positivos_usuario_3, colunas_categorias, 
                                                           total_usuario_3)
frequencia_categorias_negativos_usuario_3 = tabula_colunas(negativos_usuario_3, recorte_negativos_usuario_3, colunas_categorias, 
                                                           total_usuario_3)
# tabulação das questões encontradas nos registros e categorizadas
# atenção: um registro pode ter sido categorizado em mais de uma questão e há quatro níveis hierárquicos de categorias
consolidado_macrocategorias_usuario_3 = tabula_questoes(frequencia_categorias_usuario_3, frequencia_categorias_positivos_usuario_3, 
                                                        frequencia_categorias_negativos_usuario_3, 'F.A.', 'F.R.', 'Categoria', 59)
display(consolidado_macrocategorias_usuario_3)

# %%
# gera tabela resumida apenas com as macrocategorias/ métodos usados na análise
consolidado_metodos_usuario_3 = extratifica_tabela(consolidado_macrocategorias_usuario_3, indices_macrocategorias, 
                                                   'Método/ Macrocategoria')
# gera tabela resumida apenas com as categorias (segundo nível de classificação)
consolidado_categorias_usuario_3 = extratifica_tabela(consolidado_macrocategorias_usuario_3, indices_categorias, 
                                                      'Categoria')
# gera tabela resumida apenas com as subcategorias (terceiro nível de classificação)
consolidado_subcategorias_usuario_3 = extratifica_tabela(consolidado_macrocategorias_usuario_3, indices_subcategorias, 
                                                         'Subcategoria')
# gera tabela resumida apenas com os subtipos (quarto nível de classificação)
consolidado_subtipos_usuario_3 = extratifica_tabela(consolidado_macrocategorias_usuario_3, indices_subtipos, 'Subtipo')

# exibe tabelas
display(consolidado_metodos_usuario_3)
display(consolidado_categorias_usuario_3)
display(consolidado_subcategorias_usuario_3)
display(consolidado_subtipos_usuario_3)

# %% [markdown]
# #### **Nuvens de palavras**

# %%
# gera nuvem completa do usuário 3
comentarios_usuario_3 = ' '.join(usuario_3["Comentário"].tolist())
cores_3 = ["#000AC4", "#DB047E"]
cria_nuvem(comentarios_usuario_3,lista_stopwords,mascara_covid,cores_3,'nuvem_geral_id3.png')

# %%
# gera nuvem de registros com viés positivo do usuário 3
comentarios_positivos_usuario_3 = ' '.join(positivos_usuario_3["Comentário"].tolist())
cria_nuvem(comentarios_positivos_usuario_3,lista_stopwords,mascara_covid,cores_3,'nuvem_positivos_id3.png')

# %%
# gera nuvem de registros com viés negativo do usuário 3
comentarios_negativos_usuario_3 = ' '.join(negativos_usuario_3["Comentário"].tolist())
cria_nuvem(comentarios_negativos_usuario_3,lista_stopwords,mascara_covid,cores_3,'nuvem_negativos_id3.png')

# %% [markdown]
# ## **Outros gráficos**

# %%
# calcula correlação entre todos os tipos e níveis de classificação
categorias = paineis_covid.iloc[:,colunas_categorias].copy()
correlacoes = categorias.corr()
# ajusta o tamanho do heatmap
plt.figure(figsize = (20, 18)) 
# cria heatmap
sns.heatmap(correlacoes.abs(), cmap = "PuBu", annot = False)
# faz anotação dos valores na células do heatmap
anota_heatmap(correlacoes, fmt = ".2f", tamanho = 5)
plt.show()

# %%
# calcula correlação entre macrocategorias/ métodos
colunas_macrocategorias = list([8,34,63])
macrocategorias = paineis_covid.iloc[:,colunas_macrocategorias].copy()
correlacoes_macrocategorias = macrocategorias.corr()
# ajusta o tamanho do heatmap
plt.figure(figsize = (4, 3)) 
# cria heatmap
sns.heatmap(correlacoes_macrocategorias.abs(), cmap = "PuBu", annot = False)
# faz anotação dos valores na células do heatmap
anota_heatmap(correlacoes_macrocategorias, fmt = ".2f", tamanho = 8)
plt.show()

# %%
# calcula correlação entre categorias
colunas_categorias_n1 = list([9,16,21,24,27,31,32,33,35,43,60,64,65,66])
categorias = paineis_covid.iloc[:,colunas_categorias_n1].copy()
correlacoes_categorias = categorias.corr()
# ajusta o tamanho do heatmap
plt.figure(figsize = (10, 8)) 
# cria heatmap
sns.heatmap(correlacoes_categorias.abs(), cmap = "PuBu", annot = False)
# faz anotação dos valores na células do heatmap
anota_heatmap(correlacoes_categorias, fmt = ".2f", tamanho = 8)
plt.show()

# %% [markdown]
# ## **Tabulação dos resultados do RGT de acordo com a categorização fundamentada**

# %%
# construtos analisados por usuário
total_construtos_rgt = len(resultados_rgt.index)
frequencia_usuarios_rgt = tabula(resultados_rgt["Usuário"], total_construtos_rgt)
display(frequencia_usuarios_rgt)

# %%
# construtos analisados por categoria
linhas_recorte_rgt = range(0,12)
colunas_categorias_rgt = range(6, 65)
frequencia_categorias_rgt = tabula_colunas(resultados_rgt, linhas_recorte_rgt, colunas_categorias_rgt, total_construtos_rgt)
display(frequencia_categorias_rgt)

# %%
# tabulação geral das categorias por questões encontradas nos construtos e categorizadas
macrocategorias_rgt = frequencia_categorias_rgt.copy()
total_problemas_rgt = tabula_macrocategorias(macrocategorias_rgt, 'F.A.', 'F.R.')
display(total_problemas_rgt)
display(macrocategorias_rgt)

# %%
# gera tabela resumida apenas com as macrocategorias/ métodos usados na análise dos construtos
metodos_rgt = extratifica_tabela(macrocategorias_rgt, indices_macrocategorias, 'Método/Macrocategoria')
# gera tabela resumida apenas com as categorias (segundo nível de classificação)
categorias_rgt = extratifica_tabela(macrocategorias_rgt, indices_categorias, 'Categoria')
# gera tabela resumida apenas com as subcategorias (terceiro nível de classificação)
subcategorias_rgt = extratifica_tabela(macrocategorias_rgt, indices_subcategorias, 'Subcategoria')
# gera tabela resumida apenas com os subtipos (quarto nível de classificação)
subtipos_rgt = extratifica_tabela(macrocategorias_rgt, indices_subtipos, 'Subtipo')

# exibe tabelas
display(metodos_rgt)
display(categorias_rgt)
display(subcategorias_rgt)
display(subtipos_rgt)

# %%
# pré-tratamento do dataframe
categorias_rgt.reset_index(inplace = True, drop = False)
categorias_rgt['Categoria'] = {0: 'Condução', 1: 'Carga de Trabalho', 2: 'Controle Explícito', 3: 'Adaptabilidade', 
                                       4: 'Gestão de Erros', 5: 'Coerência/Consistência (Homogeneidade)', 
                                       6: 'Significado dos Códigos e Denominações', 7: 'Compatibilidade', 
                                       8: 'Qualidade Pragmática', 9: 'Qualidade Hedônica', 10: 'Construtos Avaliativos',
                                       11: 'Agência', 12: 'Legibilidade', 13: 'Negociabilidade', 14: 'Total'}
categorias_rgt['Macro'] = {0: 'CEU', 1: 'CEU', 2: 'CEU', 3: 'CEU', 4: 'CEU', 5: 'CEU', 6: 'CEU', 7: 'CEU', 
                                       8: 'UX', 9: 'UX', 10: 'UX',
                                       11: 'IHD', 12: 'IHD', 13: 'IHD', 14: 'Total'}

display(categorias_rgt)

# %%
# gera gráfico de questões levantadas nos construtos por categoria e macrocategoria
# define parâmetros de informação
titulo = "Pontos observados nos resultados do RGT por categoria"
linha_fina = "Número de questões elicitadas por meio dos construtos analisados"
fonte = "Fonte: a autora"
nome_arquivo = 'questoes_categoria_geral_rgt.png'
limite_cor = 3
# define intervalo de grande e o limite máximo do eixo x
intervalo = [i * 5 for i in range(4)] # define exibição de múltiplos de 10 no eixo x
limite_max_x = 17


gera_grafico_categorias(categorias_rgt, 'F.A.', 'Categoria', 0.1, titulo, linha_fina, fonte, nome_arquivo, limite_cor, limite_max_x,
                  intervalo, cor_ceu, cor_ux, cor_ihd)

# %%
# calcula correlação entre todos os tipos e níveis de classificação
categorias_rgt = resultados_rgt.iloc[:,colunas_categorias_rgt].copy()
correlacoes_rgt = categorias_rgt.corr()
# ajusta o tamanho do heatmap
plt.figure(figsize = (20, 18)) 
# cria heatmap
sns.heatmap(correlacoes_rgt.abs(), cmap = "PuBu", annot = False)
# faz anotação dos valores na células do heatmap
anota_heatmap(correlacoes_rgt, fmt = ".2f", tamanho = 5)
plt.show()

# %%
# calcula correlação entre macrocategorias/ métodos
colunas_macrocategorias_rgt = list([6,32,61])
macrocategorias_rgt = resultados_rgt.iloc[:,colunas_macrocategorias_rgt].copy()
correlacoes_macrocategorias_rgt = macrocategorias_rgt.corr()
# ajusta o tamanho do heatmap
plt.figure(figsize = (4, 3)) 
# cria heatmap
sns.heatmap(correlacoes_macrocategorias_rgt.abs(), cmap = "PuBu", annot = False)
# faz anotação dos valores na células do heatmap
anota_heatmap(correlacoes_macrocategorias_rgt, fmt = ".2f", tamanho = 8)
plt.show()

# %%
# calcula correlação entre categorias
colunas_categorias_n1_rgt = list([7,14,19,22,25,29,30,31,33,41,58,62,63,64])
categorias_rgt = resultados_rgt.iloc[:,colunas_categorias_n1_rgt].copy()
correlacoes_categorias_rgt = categorias_rgt.corr()
# ajusta o tamanho do heatmap
plt.figure(figsize = (10, 8)) 
# cria heatmap
sns.heatmap(correlacoes_categorias_rgt.abs(), cmap = "PuBu", annot = False)
# faz anotação dos valores na células do heatmap
anota_heatmap(correlacoes_categorias_rgt, fmt = ".2f", tamanho = 8)
plt.show()
